# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('fifa21 raw data v2.csv', low_memory = False)

# %%
df
# Out:
#            ID               Name                      LongName  \
# 0      158023           L. Messi                  Lionel Messi
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2      200389           J. Oblak                     Jan Oblak
# 3      192985       K. De Bruyne               Kevin De Bruyne
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...       ...                ...                           ...
# 18974  247223             Xia Ao                        Ao Xia
# 18975  258760           B. Hough                     Ben Hough
# 18976  252757        R. McKinley                Ronan McKinley
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# 18978  252520          Zhou Xiao                     Xiao Zhou
#
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/247/223/21_60.png
# 18975  https://cdn.sofifa.com/players/258/760/21_60.png
# 18976  https://cdn.sofifa.com/players/252/757/21_60.png
# 18977  https://cdn.sofifa.com/players/243/790/21_60.png
# 18978  https://cdn.sofifa.com/players/252/520/21_60.png
#
#                                                playerUrl Nationality  Age  \
# 0      http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33
# 1      http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35
# 2      http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia   27
# 3      http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium   29
# 4      http://sofifa.com/player/190871/neymar-da-silv...      Brazil   28
# ...                                                  ...         ...  ...
# 18974     http://sofifa.com/player/247223/ao-xia/210006/    China PR   21
# 18975  http://sofifa.com/player/258760/ben-hough/210006/     England   17
# 18976  http://sofifa.com/player/252757/ronan-mckinley...     England   18
# 18977  http://sofifa.com/player/243790/zhenao-wang/21...    China PR   20
# 18978  http://sofifa.com/player/252520/xiao-zhou/210006/    China PR   21
#
#        ↓OVA  POT                         Club  ...     A/W     D/W   IR PAC  \
# 0        93   93         \n\n\n\nFC Barcelona  ...  Medium     Low  5 ★  85
# 1        92   92             \n\n\n\nJuventus  ...    High     Low  5 ★  89
# 2        91   93      \n\n\n\nAtlético Madrid  ...  Medium  Medium  3 ★  87
# 3        91   91      \n\n\n\nManchester City  ...    High    High  4 ★  76
# 4        91   91  \n\n\n\nParis Saint-Germain  ...    High  Medium  5 ★  91
# ...     ...  ...                          ...  ...     ...     ...  ...  ..
# 18974    47   55           \n\n\n\nWuhan Zall  ...  Medium  Medium  1 ★  64
# 18975    47   67      \n\n\n\nOldham Athletic  ...  Medium  Medium  1 ★  64
# 18976    47   65           \n\n\n\nDerry City  ...  Medium  Medium  1 ★  63
# 18977    47   57     \n\n\n\nDalian YiFang FC  ...  Medium  Medium  1 ★  58
# 18978    47   57     \n\n\n\nDalian YiFang FC  ...  Medium  Medium  1 ★  62
#
#       SHO  PAS DRI DEF PHY Hits
# 0      92   91  95  38  65  771
# 1      93   81  89  35  77  562
# 2      92   78  90  52  90  150
# 3      86   93  88  64  78  207
# 4      85   86  94  36  59  595
# ...    ..  ...  ..  ..  ..  ...
# 18974  28   26  38  48  51  NaN
# 18975  40   48  49  35  45  NaN
# 18976  39   44  46  40  53  NaN
# 18977  49   41  49  30  44  NaN
# 18978  22   39  42  45  55  NaN
#
# [18979 rows x 77 columns]

# %%
df.dtypes
# Out:
# ID            int64
# Name         object
# LongName     object
# photoUrl     object
# playerUrl    object
#               ...
# PAS           int64
# DRI           int64
# DEF           int64
# PHY           int64
# Hits         object
# Length: 77, dtype: object

# %%
df.describe()
# Out:
#                   ID           Age          ↓OVA           POT           BOV  \
# count   18979.000000  18979.000000  18979.000000  18979.000000  18979.000000
# mean   226403.384794     25.194109     65.718636     71.136414     66.751726
# std     27141.054157      4.710520      6.968999      6.114635      6.747193
# min        41.000000     16.000000     47.000000     47.000000     48.000000
# 25%    210135.000000     21.000000     61.000000     67.000000     62.000000
# 50%    232418.000000     25.000000     66.000000     71.000000     67.000000
# 75%    246922.500000     29.000000     70.000000     75.000000     71.000000
# max    259216.000000     53.000000     93.000000     95.000000     93.000000
#
#           Attacking      Crossing     Finishing  Heading Accuracy  \
# count  18979.000000  18979.000000  18979.000000      18979.000000
# mean     248.938142     49.688392     45.842405         51.942726
# std       74.299428     18.131153     19.567081         17.294409
# min       42.000000      6.000000      3.000000          5.000000
# 25%      222.000000     38.000000     30.000000         44.000000
# 50%      263.000000     54.000000     49.000000         55.000000
# 75%      297.000000     63.000000     62.000000         64.000000
# max      437.000000     94.000000     95.000000         93.000000
#
#        Short Passing  ...  GK Positioning   GK Reflexes   Total Stats  \
# count   18979.000000  ...    18979.000000  18979.000000  18979.000000
# mean       58.768112  ...       16.217187     16.519627   1595.286949
# std        14.519106  ...       17.002239     17.854079    269.874789
# min         7.000000  ...        2.000000      2.000000    747.000000
# 25%        54.000000  ...        8.000000      8.000000   1452.000000
# 50%        62.000000  ...       11.000000     11.000000   1627.000000
# 75%        68.000000  ...       14.000000     14.000000   1781.000000
# max        94.000000  ...       91.000000     90.000000   2316.000000
#
#          Base Stats           PAC           SHO           PAS           DRI  \
# count  18979.000000  18979.000000  18979.000000  18979.000000  18979.000000
# mean     355.702197     67.453975     53.457031     57.681016     62.875020
# std       40.761117     10.677859     13.827425     10.081857      9.927415
# min      232.000000     25.000000     16.000000     25.000000     25.000000
# 25%      327.000000     61.000000     44.000000     51.000000     57.000000
# 50%      356.000000     68.000000     56.000000     58.000000     64.000000
# 75%      384.000000     75.000000     64.000000     64.000000     69.000000
# max      498.000000     96.000000     93.000000     93.000000     95.000000
#
#                 DEF           PHY
# count  18979.000000  18979.000000
# mean      49.866221     64.368934
# std       16.443213      9.601883
# min       12.000000     28.000000
# 25%       35.000000     58.000000
# 50%       53.000000     65.000000
# 75%       63.000000     71.000000
# max       91.000000     91.000000
#
# [8 rows x 54 columns]

# %%
df.isna().sum()
# Out:
# ID              0
# Name            0
# LongName        0
# photoUrl        0
# playerUrl       0
#              ...
# PAS             0
# DRI             0
# DEF             0
# PHY             0
# Hits         2595
# Length: 77, dtype: int64

# %%
df['Hits'].value_counts()
# Out:
# 1      2337
# 2      2243
# 3      1733
# 4      1248
# 5       936
#        ...
# 254       1
# 565       1
# 375       1
# 605       1
# 6K        1
# Name: Hits, Length: 439, dtype: int64

# %%
Nan_percent = df.isna().sum()/len(df)

# %%
pd.DataFrame(Nan_percent, columns = ['Nan Percent Value']).head(50)
# Out:
#                   Nan Percent Value
# ID                         0.000000
# Name                       0.000000
# LongName                   0.000000
# photoUrl                   0.000000
# playerUrl                  0.000000
# Nationality                0.000000
# Age                        0.000000
# ↓OVA                       0.000000
# POT                        0.000000
# Club                       0.000000
# Contract                   0.000000
# Positions                  0.000000
# Height                     0.000000
# Weight                     0.000000
# Preferred Foot             0.000000
# BOV                        0.000000
# Best Position              0.000000
# Joined                     0.000000
# Loan Date End              0.946625
# Value                      0.000000
# Wage                       0.000000
# Release Clause             0.000000
# Attacking                  0.000000
# Crossing                   0.000000
# Finishing                  0.000000
# Heading Accuracy           0.000000
# Short Passing              0.000000
# Volleys                    0.000000
# Skill                      0.000000
# Dribbling                  0.000000
# Curve                      0.000000
# FK Accuracy                0.000000
# Long Passing               0.000000
# Ball Control               0.000000
# Movement                   0.000000
# Acceleration               0.000000
# Sprint Speed               0.000000
# Agility                    0.000000
# Reactions                  0.000000
# Balance                    0.000000
# Power                      0.000000
# Shot Power                 0.000000
# Jumping                    0.000000
# Stamina                    0.000000
# Strength                   0.000000
# Long Shots                 0.000000
# Mentality                  0.000000
# Aggression                 0.000000
# Interceptions              0.000000
# Positioning                0.000000

# %%
pd.DataFrame(Nan_percent, columns = ['Nan Percent Value']).tail(27)
# Out:
#                  Nan Percent Value
# Vision                     0.00000
# Penalties                  0.00000
# Composure                  0.00000
# Defending                  0.00000
# Marking                    0.00000
# Standing Tackle            0.00000
# Sliding Tackle             0.00000
# Goalkeeping                0.00000
# GK Diving                  0.00000
# GK Handling                0.00000
# GK Kicking                 0.00000
# GK Positioning             0.00000
# GK Reflexes                0.00000
# Total Stats                0.00000
# Base Stats                 0.00000
# W/F                        0.00000
# SM                         0.00000
# A/W                        0.00000
# D/W                        0.00000
# IR                         0.00000
# PAC                        0.00000
# SHO                        0.00000
# PAS                        0.00000
# DRI                        0.00000
# DEF                        0.00000
# PHY                        0.00000
# Hits                       0.13673

# %%
df['Loan Date End']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 18974    NaN
# 18975    NaN
# 18976    NaN
# 18977    NaN
# 18978    NaN
# Name: Loan Date End, Length: 18979, dtype: object

# %%
df['Loan Date End'].unique()
# Out:
# array([nan, 'Jun 30, 2021', 'Dec 31, 2020', 'Jan 30, 2021',
#        'Jun 30, 2022', 'May 31, 2021', 'Jul 5, 2021', 'Dec 31, 2021',
#        'Jul 1, 2021', 'Jan 1, 2021', 'Aug 31, 2021', 'Jan 31, 2021',
#        'Dec 30, 2021', 'Jun 23, 2021', 'Jan 3, 2021', 'Nov 27, 2021',
#        'Jan 17, 2021', 'Jun 30, 2023', 'Jul 31, 2021', 'Nov 22, 2020',
#        'May 31, 2022', 'Dec 30, 2020', 'Jan 4, 2021', 'Nov 30, 2020',
#        'Aug 1, 2021'], dtype=object)

# %%
df['Loan Date End'].value_counts()
# Out:
# Jun 30, 2021    770
# Dec 31, 2020    100
# May 31, 2021     30
# Dec 31, 2021     22
# Jan 31, 2021     18
# Jan 1, 2021      15
# Jun 30, 2022     15
# Nov 30, 2020      7
# Jun 23, 2021      7
# Nov 27, 2021      6
# Nov 22, 2020      5
# Jan 3, 2021       3
# Aug 31, 2021      2
# May 31, 2022      2
# Jan 4, 2021       2
# Jul 1, 2021       1
# Dec 30, 2021      1
# Jul 5, 2021       1
# Jan 17, 2021      1
# Jun 30, 2023      1
# Jul 31, 2021      1
# Dec 30, 2020      1
# Jan 30, 2021      1
# Aug 1, 2021       1
# Name: Loan Date End, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
#  16  Best Position     18979 non-null  object
#  17  Joined            18979 non-null  object
#  18  Loan Date End     1013 non-null   object
#  19  Value             18979 non-null  object
#  20  Wage              18979 non-null  object
#  21  Release Clause    18979 non-null  object
#  22  Attacking         18979 non-null  int64
#  23  Crossing          18979 non-null  int64
#  24  Finishing         18979 non-null  int64
#  25  Heading Accuracy  18979 non-null  int64
#  26  Short Passing     18979 non-null  int64
#  27  Volleys           18979 non-null  int64
#  28  Skill             18979 non-null  int64
#  29  Dribbling         18979 non-null  int64
#  30  Curve             18979 non-null  int64
#  31  FK Accuracy       18979 non-null  int64
#  32  Long Passing      18979 non-null  int64
#  33  Ball Control      18979 non-null  int64
#  34  Movement          18979 non-null  int64
#  35  Acceleration      18979 non-null  int64
#  36  Sprint Speed      18979 non-null  int64
#  37  Agility           18979 non-null  int64
#  38  Reactions         18979 non-null  int64
#  39  Balance           18979 non-null  int64
#  40  Power             18979 non-null  int64
#  41  Shot Power        18979 non-null  int64
#  42  Jumping           18979 non-null  int64
#  43  Stamina           18979 non-null  int64
#  44  Strength          18979 non-null  int64
#  45  Long Shots        18979 non-null  int64
#  46  Mentality         18979 non-null  int64
#  47  Aggression        18979 non-null  int64
#  48  Interceptions     18979 non-null  int64
#  49  Positioning       18979 non-null  int64
#  50  Vision            18979 non-null  int64
#  51  Penalties         18979 non-null  int64
#  52  Composure         18979 non-null  int64
#  53  Defending         18979 non-null  int64
#  54  Marking           18979 non-null  int64
#  55  Standing Tackle   18979 non-null  int64
#  56  Sliding Tackle    18979 non-null  int64
#  57  Goalkeeping       18979 non-null  int64
#  58  GK Diving         18979 non-null  int64
#  59  GK Handling       18979 non-null  int64
#  60  GK Kicking        18979 non-null  int64
#  61  GK Positioning    18979 non-null  int64
#  62  GK Reflexes       18979 non-null  int64
#  63  Total Stats       18979 non-null  int64
#  64  Base Stats        18979 non-null  int64
#  65  W/F               18979 non-null  object
#  66  SM                18979 non-null  object
#  67  A/W               18979 non-null  object
#  68  D/W               18979 non-null  object
#  69  IR                18979 non-null  object
#  70  PAC               18979 non-null  int64
#  71  SHO               18979 non-null  int64
#  72  PAS               18979 non-null  int64
#  73  DRI               18979 non-null  int64
#  74  DEF               18979 non-null  int64
#  75  PHY               18979 non-null  int64
#  76  Hits              16384 non-null  object
# dtypes: int64(54), object(23)
# memory usage: 11.1+ MB

# %%
df.shape
# Out:
# (18979, 77)

# %%
df['Hits'].describe()
# Out:
# count     16384
# unique      439
# top           1
# freq       2337
# Name: Hits, dtype: object

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
#        'DRI', 'DEF', 'PHY', 'Hits'],
#       dtype='object')

# %%
df = df.drop(columns=['Loan Date End'])

# %%
df.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia   27    91
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium   29    91
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil   28    91
#
#    POT                         Club  ...     A/W     D/W   IR PAC SHO  PAS  \
# 0   93         \n\n\n\nFC Barcelona  ...  Medium     Low  5 ★  85  92   91
# 1   92             \n\n\n\nJuventus  ...    High     Low  5 ★  89  93   81
# 2   93      \n\n\n\nAtlético Madrid  ...  Medium  Medium  3 ★  87  92   78
# 3   91      \n\n\n\nManchester City  ...    High    High  4 ★  76  86   93
# 4   91  \n\n\n\nParis Saint-Germain  ...    High  Medium  5 ★  91  85   86
#
#   DRI DEF PHY Hits
# 0  95  38  65  771
# 1  89  35  77  562
# 2  90  52  90  150
# 3  88  64  78  207
# 4  94  36  59  595
#
# [5 rows x 76 columns]

# %%
df['Hits'].unique()
# Out:
# array(['771', '562', '150', '207', '595', '248', '246', '120', '1.6K',
#        '130', '321', '189', '175', '96', '118', '216', '212', '154',
#        '205', '202', '339', '408', '103', '332', '86', '173', '161',
#        '396', '1.1K', '433', '242', '206', '177', '1.5K', '198', '459',
#        '117', '119', '209', '84', '187', '165', '203', '65', '336', '126',
#        '313', '124', '145', '538', '182', '101', '45', '377', '99', '194',
#        '403', '414', '593', '374', '245', '3.2K', '266', '299', '309',
#        '215', '265', '211', '112', '337', '70', '159', '688', '116', '63',
#        '144', '123', '71', '224', '113', '168', '61', '89', '137', '278',
#        '75', '148', '176', '197', '264', '214', '247', '402', '440',
#        '1.7K', '2.3K', '171', '320', '657', '87', '259', '200', '255',
#        '253', '196', '60', '97', '85', '169', '256', '132', '239', '166',
#        '121', '109', '32', '46', '122', '48', '527', '199', '282', '51',
#        '1.9K', '642', '155', '323', '288', '497', '509', '79', '49',
#        '270', '511', '80', '128', '115', '156', '204', '143', '140',
#        '152', '220', '134', '225', '94', '74', '135', '142', '50', '77',
#        '40', '107', '193', '179', '34', '64', '453', '57', '81', '28',
#        '78', '133', '43', '425', '88', '42', '36', '233', '376', '210',
#        '444', '100', '263', '98', '29', '160', '39', '257', '6', '310',
#        '138', '62', '293', '285', '362', '66', '69', '58', '21', '20',
#        '131', '38', '406', '68', '108', '110', '93', '512', '443', '306',
#        '352', '422', '585', '346', '178', '841', '76', '394', '72', '172',
#        '44', '407', '230', '367', '295', '157', '243', '56', '111', '326',
#        '679', '18', '92', '59', '25', '184', '53', '12', '90', '55', '73',
#        '11', '566', '180', '83', '262', '17', '26', '31', '280', '359',
#        '213', '297', '387', '480', '381', '677', '486', '8', '244', '129',
#        '388', '275', '319', '2K', '52', '91', '421', '153', '27', '41',
#        '222', '35', '102', '23', '30', '33', '146', '13', '19', '14',
#        '106', '276', '568', '353', '47', '478', '249', '254', '369',
#        '219', '565', '237', '227', '434', '375', '162', '605', '654', '3',
#        '7', '9', '104', '114', '186', '446', '756', '22', '139', '500',
#        '67', '147', '149', '16', '82', '54', '37', '15', '1.3K', '3K',
#        '952', '5', '749', '541', '330', '393', '517', '770', '409', '170',
#        '125', '283', '342', '363', '580', '105', '217', '24', '141', '10',
#        '427', '158', '426', '4', '666', '181', '324', '979', '1.4K',
#        '302', '751', '298', '411', '944', '2', '947', '292', '349', '621',
#        '1', '2.8K', '338', '287', '261', '218', '1.8K', '240', '279',
#        '229', '188', '315', '664', '613', '190', '706', '127', '462',
#        '386', '695', '491', '167', '281', '250', '307', '95', '231',
#        '174', '680', '633', '221', '348', '602', '183', '653', '195',
#        '164', '151', '258', '8.4K', '343', '419', '655', '136', '399',
#        '531', '357', '228', '385', '312', '340', '238', '487', '355',
#        '499', '4.3K', '296', '515', '943', '1.2K', '903', '335', '191',
#        '594', '267', '617', '516', '504', '331', '652', '410', '550',
#        '473', '442', '344', '208', '1K', '2.5K', '273', '485', '826',
#        '192', '405', '941', '477', '644', '303', '417', '6K', nan],
#       dtype=object)

# %%
df['ID']
# Out:
# 0        158023
# 1         20801
# 2        200389
# 3        192985
# 4        190871
#           ...
# 18974    247223
# 18975    258760
# 18976    252757
# 18977    243790
# 18978    252520
# Name: ID, Length: 18979, dtype: int64

# %%
df = df.sort_values(by = 'ID')

# %%
df
# Out:
#            ID             Name               LongName  \
# 350        41          Iniesta   Andrés Iniesta Luján
# 262      1179        G. Buffon       Gianluigi Buffon
# 3348     2147  M. Stekelenburg   Maarten Stekelenburg
# 16621    2702       K. Ellison          Kevin Ellison
# 3730     3281        Tarantini  Ricardo José Monteiro
# ...       ...              ...                    ...
# 12547  259209      M. Bajamich         Mateo Bajamich
# 15200  259211       O. Özdoğan          Oytun Özdoğan
# 16935  259212       S. Ottesen         Sturla Ottesen
# 12532  259214        W. Jooste           Wayde Jooste
# 18227  259216       F. Seferaj        Florjan Seferaj
#
#                                                photoUrl  \
# 350    https://cdn.sofifa.com/players/000/041/21_60.png
# 262    https://cdn.sofifa.com/players/001/179/21_60.png
# 3348   https://cdn.sofifa.com/players/002/147/21_60.png
# 16621  https://cdn.sofifa.com/players/002/702/21_60.png
# 3730   https://cdn.sofifa.com/players/003/281/21_60.png
# ...                                                 ...
# 12547  https://cdn.sofifa.com/players/259/209/21_60.png
# 15200  https://cdn.sofifa.com/players/259/211/21_60.png
# 16935  https://cdn.sofifa.com/players/259/212/21_60.png
# 12532  https://cdn.sofifa.com/players/259/214/21_60.png
# 18227  https://cdn.sofifa.com/players/259/216/21_60.png
#
#                                                playerUrl   Nationality  Age  \
# 350    http://sofifa.com/player/41/andres-iniesta-luj...         Spain   36
# 262    http://sofifa.com/player/1179/gianluigi-buffon...         Italy   42
# 3348   http://sofifa.com/player/2147/maarten-stekelen...   Netherlands   37
# 16621  http://sofifa.com/player/2702/kevin-ellison/21...       England   41
# 3730   http://sofifa.com/player/3281/ricardo-jose-mon...      Portugal   36
# ...                                                  ...           ...  ...
# 12547  http://sofifa.com/player/259209/mateo-bajamich...     Argentina   20
# 15200  http://sofifa.com/player/259211/oytun-ozdogan/...        Turkey   22
# 16935  http://sofifa.com/player/259212/sturla-ottesen...        Norway   19
# 12532  http://sofifa.com/player/259214/wayde-jooste/2...  South Africa   28
# 18227  http://sofifa.com/player/259216/florjan-sefera...   Switzerland   19
#
#        ↓OVA  POT                     Club  ...     A/W     D/W   IR PAC SHO  \
# 350      81   81      \n\n\n\nVissel Kobe  ...    High  Medium  4 ★  58  70
# 262      82   82         \n\n\n\nJuventus  ...  Medium  Medium  4 ★  77  76
# 3348     72   72             \n\n\n\nAjax  ...  Medium  Medium  2 ★  69  71
# 16621    58   58   \n\n\n\nNewport County  ...    High     Low  1 ★  43  63
# 3730     72   72       \n\n\n\nRio Ave FC  ...  Medium  Medium  1 ★  50  67
# ...     ...  ...                      ...  ...     ...     ...  ...  ..  ..
# 12547    63   78   \n\n\n\nHouston Dynamo  ...    High    High  1 ★  71  60
# 15200    60   68    \n\n\n\nFenerbahçe SK  ...  Medium  Medium  1 ★  59  60
# 16935    57   73   \n\n\n\nStabæk Fotball  ...  Medium  Medium  1 ★  63  33
# 12532    63   63  \n\n\n\nOrlando Pirates  ...    High  Medium  1 ★  68  64
# 18227    53   64        \n\n\n\nFC Lugano  ...  Medium     Low  1 ★  56  58
#
#        PAS DRI DEF PHY Hits
# 350     85  85  63  59  130
# 262     74  78  33  91  131
# 3348    72  70  33  73   23
# 16621   56  63  43  72  NaN
# 3730    71  70  70  67    4
# ...    ...  ..  ..  ..  ...
# 12547   52  63  27  57    3
# 15200   64  61  24  62    4
# 16935   45  53  56  61  NaN
# 12532   59  67  30  53    2
# 18227   39  47  20  50  NaN
#
# [18979 rows x 76 columns]

# %%
df.dtypes
# Out:
# ID            int64
# Name         object
# LongName     object
# photoUrl     object
# playerUrl    object
#               ...
# PAS           int64
# DRI           int64
# DEF           int64
# PHY           int64
# Hits         object
# Length: 76, dtype: object

# %%
df = df.fillna(0)

# %%
df.shape
# Out:
# (16384, 76)

# %%
df[['Contract']]
# Out:
#           Contract
# 350    2018 ~ 2021
# 262    2019 ~ 2021
# 3348   2020 ~ 2021
# 3730   2008 ~ 2021
# 4207   2017 ~ 2021
# ...            ...
# 15843  2020 ~ 2024
# 12487  2020 ~ 2023
# 12547  2020 ~ 2022
# 15200  2018 ~ 2021
# 12532  2020 ~ 2024
#
# [16384 rows x 1 columns]

# %%
df['Contract'] = df['Contract'].str.replace('~',  '-')
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\3471104056.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Contract'] = df['Contract'].str.replace('~',  '-')

# %%
df['Contract'].unique()
# Out:
# array(['2018 - 2021', '2019 - 2021', '2020 - 2021', '2008 - 2021',
#        '2017 - 2021', '2014 - 2021', '2016 - 2021', '2020 - 2022',
#        '2018 - 2022', '2016 - 2023', '2007 - 2020', '2015 - 2021',
#        '2020 - 2020', '2019 - 2020', '2003 - 2022', '2018 - 2023',
#        '2011 - 2021', '2015 - 2020', '2018 - 2020', '2013 - 2021',
#        '2019 - 2025', 'Jun 30, 2021 On Loan', '2010 - 2021',
#        '2020 - 2023', '2017 - 2022', 'Free', '2007 - 2021', '2012 - 2021',
#        '2009 - 2020', '2015 - 2022', '2002 - 2021', '2019 - 2023',
#        '2005 - 2021', '2019 - 2022', '1998 - 2021', '2019 - 2024',
#        '2006 - 2021', '2003 - 2020', '2016 - 2020', '2014 - 2022',
#        'May 31, 2021 On Loan', '2003 - 2021', '2015 - 2024',
#        '2010 - 2024', '2002 - 2022', '2014 - 2020', '2004 - 2021',
#        '2006 - 2020', '2008 - 2022', '2012 - 2020', '2020 - 2024',
#        '2008 - 2020', '2016 - 2024', '2009 - 2021', '2010 - 2020',
#        '2013 - 2020', '2020 - 2025', '2011 - 2025', '2011 - 2023',
#        '2018 - 2025', '2017 - 2024', '2017 - 2023', '2009 - 2022',
#        '2004 - 2025', '2007 - 2025', '2012 - 2022', '2017 - 2020',
#        '2017 - 2025', '2014 - 2023', '2011 - 2022', '2012 - 2025',
#        '2013 - 2022', '2016 - 2022', '2011 - 2020', '2010 - 2022',
#        '2005 - 2022', '2013 - 2025', 'Dec 31, 2020 On Loan',
#        '2006 - 2023', '2007 - 2022', '2015 - 2023', '2010 - 2023',
#        '2018 - 2024', '2013 - 2023', '2004 - 2020', '2006 - 2024',
#        '2014 - 2024', '2005 - 2023', '2002 - 2020',
#        'Jan 30, 2021 On Loan', 'Jan 1, 2021 On Loan', '2007 - 2023',
#        '2012 - 2023', '2012 - 2024', '2008 - 2023', '2009 - 2024',
#        'Dec 31, 2021 On Loan', '2016 - 2025', '2014 - 2025',
#        '2011 - 2024', '2009 - 2023', '2010 - 2025', '2015 - 2025',
#        'Jan 31, 2021 On Loan', 'Jul 5, 2021 On Loan',
#        'Jun 30, 2022 On Loan', '2016 - 2026', '2013 - 2024',
#        '2013 - 2026', '2020 - 2026', '2012 - 2028',
#        'Nov 22, 2020 On Loan', 'Nov 27, 2021 On Loan',
#        'Jun 23, 2021 On Loan', 'Jan 17, 2021 On Loan', '2005 - 2020',
#        '2014 - 2026', 'Jul 1, 2021 On Loan', 'Dec 30, 2021 On Loan',
#        'Jan 4, 2021 On Loan', 'Jan 3, 2021 On Loan', '2020 - 2027',
#        'Nov 30, 2020 On Loan', 'Aug 31, 2021 On Loan',
#        'Jul 31, 2021 On Loan', '2019 - 2026', 'May 31, 2022 On Loan',
#        'Jun 30, 2023 On Loan', 'Dec 30, 2020 On Loan'], dtype=object)

# %%
df['Contract'].value_counts()
# Out:
# 2019 - 2021             1429
# 2020 - 2022             1234
# 2020 - 2021             1153
# 2019 - 2023             1068
# 2019 - 2022             1068
#                         ...
# 2010 - 2025                1
# Jul 5, 2021 On Loan        1
# 2016 - 2026                1
# 2013 - 2026                1
# Dec 30, 2020 On Loan       1
# Name: Contract, Length: 129, dtype: int64

# %%
df['Club'].unique()
# Out:
# array(['\n\n\n\nVissel Kobe', '\n\n\n\nJuventus', '\n\n\n\nAjax',
#        '\n\n\n\nRio Ave FC', '\n\n\n\nSD Ponferradina',
#        '\n\n\n\nFC Groningen', '\n\n\n\nCrewe Alexandra',
#        '\n\n\n\nGil Vicente FC', '\n\n\n\nSporting de Charleroi',
#        '\n\n\n\nCrawley Town', '\n\n\n\nVitória Guimarães',
#        '\n\n\n\nLazio', '\n\n\n\nOlimpia Asunción', '\n\n\n\nYokohama FC',
#        '\n\n\n\nReal Salt Lake', '\n\n\n\nMilan', '\n\n\n\nReal Betis',
#        '\n\n\n\nIFK Göteborg', '\n\n\n\nSan Lorenzo de Almagro',
#        '\n\n\n\nRangers FC', '\n\n\n\nSV Zulte-Waregem',
#        '\n\n\n\nAngers SCO', '\n\n\n\nKV Mechelen',
#        '\n\n\n\nTranmere Rovers', '\n\n\n\nSK Brann',
#        '\n\n\n\nBristol City', '\n\n\n\nLeicester City',
#        '\n\n\n\nFC Lugano', '\n\n\n\nHokkaido Consadole Sapporo',
#        '\n\n\n\nLeyton Orient', '\n\n\n\nManchester United',
#        '\n\n\n\nRotherham United', '\n\n\n\nWycombe Wanderers',
#        '\n\n\n\nSheffield United', '\n\n\n\nGrimsby Town',
#        '\n\n\n\nDerby County', '\n\n\n\nSwansea City',
#        '\n\n\n\nHannover 96', '\n\n\n\nSpezia', '\n\n\n\nHertha BSC',
#        '\n\n\n\nKilmarnock', '\n\n\n\nFK Haugesund',
#        '\n\n\n\nSpVgg Unterhaching', '\n\n\n\nStandard de Liège',
#        '\n\n\n\nLegia Warszawa', '\n\n\n\nSassuolo',
#        '\n\n\n\nFC Schalke 04', '\n\n\n\nOlympique de Marseille',
#        '\n\n\n\nFC Dallas', '\n\n\n\nKV Oostende',
#        "\n\n\n\nNewell's Old Boys", '\n\n\n\nShamrock Rovers',
#        '\n\n\n\nReal Sociedad', '\n\n\n\nCD Leganés',
#        '\n\n\n\nPlymouth Argyle', '\n\n\n\nCoquimbo Unido',
#        '\n\n\n\nElche CF', '\n\n\n\nFC Cartagena',
#        '\n\n\n\nMontreal Impact', '\n\n\n\nWest Ham United',
#        '\n\n\n\nSalford City', '\n\n\n\nFC Chambly Oise',
#        '\n\n\n\nBenevento', '\n\n\n\nNottingham Forest',
#        '\n\n\n\nFC Porto', '\n\n\n\nFC Red Bull Salzburg',
#        '\n\n\n\nFSV Zwickau', '\n\n\n\nSV Sandhausen',
#        '\n\n\n\nSivasspor', '\n\n\n\nLOSC Lille', '\n\n\n\nDenizlispor',
#        '\n\n\n\nMedipol Başakşehir FK', '\n\n\n\nAntalyaspor',
#        '\n\n\n\nFC København', '\n\n\n\nYeni Malatyaspor',
#        '\n\n\n\nÇaykur Rizespor', '\n\n\n\nAlanyaspor',
#        '\n\n\n\nRochdale', '\n\n\n\nFC Midtjylland', 'No Club',
#        '\n\n\n\nBeşiktaş JK', '\n\n\n\nFC Girondins de Bordeaux',
#        '\n\n\n\nCeltic', '\n\n\n\nHelsingborgs IF',
#        '\n\n\n\nWolfsberger AC', '\n\n\n\nManchester City',
#        '\n\n\n\nJeonbuk Hyundai Motors', '\n\n\n\nSeongnam FC',
#        '\n\n\n\nKV Kortrijk', '\n\n\n\n1. FC Magdeburg',
#        '\n\n\n\nWuhan Zall', '\n\n\n\nGenoa', '\n\n\n\nParma',
#        '\n\n\n\nLiverpool', '\n\n\n\nRiver Plate',
#        '\n\n\n\nMilton Keynes Dons', '\n\n\n\nChelsea',
#        '\n\n\n\nOrlando City SC', '\n\n\n\nWestern Sydney Wanderers',
#        '\n\n\n\nPreston North End', '\n\n\n\nHarrogate Town',
#        '\n\n\n\nColchester United', '\n\n\n\nSt. Johnstone FC',
#        '\n\n\n\nArgentinos Juniors', '\n\n\n\nFC Lorient',
#        '\n\n\n\nKashima Antlers', '\n\n\n\nClub Libertad',
#        '\n\n\n\nClub América', '\n\n\n\nRoma', '\n\n\n\nDerry City',
#        '\n\n\n\nWaterford FC', '\n\n\n\nBolton Wanderers',
#        '\n\n\n\nBurton Albion', '\n\n\n\nDoncaster Rovers',
#        '\n\n\n\nCagliari', '\n\n\n\nWSG Tirol', '\n\n\n\nPeñarol',
#        '\n\n\n\nCork City', '\n\n\n\nCD Tenerife', '\n\n\n\nRacing Club',
#        '\n\n\n\nEstudiantes de La Plata', '\n\n\n\nRosario Central',
#        '\n\n\n\nClub Atlético Banfield', '\n\n\n\nShakhtar Donetsk',
#        '\n\n\n\nClub Atlético Talleres', '\n\n\n\nClub Atlético Tigre',
#        '\n\n\n\nBoca Juniors', '\n\n\n\nArsenal de Sarandí',
#        '\n\n\n\nAtalanta', '\n\n\n\nFenerbahçe SK',
#        '\n\n\n\nClub Atlético Lanús', '\n\n\n\nClub Atlético Aldosivi',
#        '\n\n\n\nGalatasaray SK', '\n\n\n\nGazişehir Gaziantep F.K.',
#        '\n\n\n\nFC Luzern', '\n\n\n\nViktoria Köln',
#        '\n\n\n\nAtiker Konyaspor', '\n\n\n\nBorussia Mönchengladbach',
#        '\n\n\n\nPerth Glory', '\n\n\n\nCD Lugo', '\n\n\n\nSD Huesca',
#        '\n\n\n\nCádiz CF', '\n\n\n\nReal Sporting de Gijón',
#        '\n\n\n\nSevilla FC', '\n\n\n\nHJK Helsinki',
#        '\n\n\n\nRCD Espanyol', '\n\n\n\nGranada CF',
#        '\n\n\n\nAthletic Club de Bilbao', '\n\n\n\nCA Osasuna',
#        '\n\n\n\nPolitehnica Iaşi', '\n\n\n\nUniversitatea Craiova',
#        '\n\n\n\nGaz Metan Mediaş', '\n\n\n\nFC Argeș',
#        '\n\n\n\nPFC CSKA Moscow', '\n\n\n\nSpartak Moscow',
#        '\n\n\n\nFC Paços de Ferreira', '\n\n\n\nOdds BK',
#        '\n\n\n\nViking FK', '\n\n\n\nCrotone', '\n\n\n\nTorino',
#        '\n\n\n\nDundalk', '\n\n\n\nCambridge United',
#        '\n\n\n\nOlympiacos CFP', '\n\n\n\nStade Rennais FC',
#        '\n\n\n\nOud-Heverlee Leuven', '\n\n\n\nParis FC',
#        '\n\n\n\nTottenham Hotspur', '\n\n\n\nLokomotiv Moscow',
#        '\n\n\n\nBeerschot AC', '\n\n\n\nSønderjyskE',
#        '\n\n\n\nSCR Altach', '\n\n\n\nBradford City', '\n\n\n\nPort Vale',
#        '\n\n\n\nMolde FK', '\n\n\n\nSouthend United',
#        '\n\n\n\nCheltenham Town', '\n\n\n\nBlackburn Rovers',
#        '\n\n\n\nNorwich City', '\n\n\n\nVålerenga Fotball',
#        '\n\n\n\nPortimonense SC', '\n\n\n\nFC Barcelona',
#        '\n\n\n\nKayserispor', '\n\n\n\nInter', '\n\n\n\nDeportivo Toluca',
#        '\n\n\n\nŚląsk Wrocław', '\n\n\n\nClub Atlético Huracán',
#        '\n\n\n\nRosenborg BK', '\n\n\n\nBologna', '\n\n\n\nAalesunds FK',
#        '\n\n\n\nColo-Colo', '\n\n\n\nSD Aucas',
#        '\n\n\n\nGimnasia y Esgrima La Plata', '\n\n\n\nMelgar FBC',
#        '\n\n\n\nTigres U.A.N.L.', '\n\n\n\nMontpellier HSC',
#        '\n\n\n\nRacing Club de Lens', '\n\n\n\nFC Botoşani',
#        '\n\n\n\nKristiansund BK', '\n\n\n\nBusan IPark',
#        '\n\n\n\nUlsan Hyundai FC', '\n\n\n\nPiast Gliwice',
#        '\n\n\n\nAstra Giurgiu', '\n\n\n\nHuddersfield Town',
#        '\n\n\n\nShrewsbury', '\n\n\n\nAC Horsens', '\n\n\n\nWarta Poznań',
#        '\n\n\n\nReal Madrid', '\n\n\n\nMillwall', '\n\n\n\nSunderland',
#        '\n\n\n\nCrystal Palace', '\n\n\n\nToronto FC',
#        '\n\n\n\nBrisbane Roar', '\n\n\n\nAberdeen', '\n\n\n\nLuton Town',
#        '\n\n\n\nWisła Płock', '\n\n\n\nRKC Waalwijk', '\n\n\n\nCruz Azul',
#        '\n\n\n\nFC Sion', '\n\n\n\nU.N.A.M.',
#        '\n\n\n\nTSG 1899 Hoffenheim', '\n\n\n\nLASK Linz',
#        '\n\n\n\nUrawa Red Diamonds', '\n\n\n\nAtlético Tucumán',
#        '\n\n\n\nFC Juárez', '\n\n\n\nAtlético Madrid',
#        '\n\n\n\nFiorentina', '\n\n\n\nBB Erzurumspor',
#        '\n\n\n\nIF Elfsborg', '\n\n\n\nCharlton Athletic',
#        '\n\n\n\nBK Häcken', "\n\n\n\nSt. Patrick's Athletic",
#        '\n\n\n\nVillarreal CF', '\n\n\n\nMazatlán FC',
#        '\n\n\n\nMSV Duisburg', '\n\n\n\nSC Paderborn 07',
#        '\n\n\n\nWestern United FC', '\n\n\n\nBristol Rovers',
#        '\n\n\n\nHamburger SV', '\n\n\n\nRCD Mallorca',
#        '\n\n\n\nSK Rapid Wien', '\n\n\n\nCF Fuenlabrada',
#        '\n\n\n\nGuangzhou Evergrande Taobao FC', '\n\n\n\nShenzhen FC',
#        '\n\n\n\nVfL Osnabrück', '\n\n\n\nGuadalajara', '\n\n\n\nOGC Nice',
#        '\n\n\n\nAS Saint-Étienne', '\n\n\n\nRB Leipzig',
#        '\n\n\n\nFC Utrecht', '\n\n\n\nOriente Petrolero',
#        '\n\n\n\n1. FC Union Berlin', '\n\n\n\nWigan Athletic',
#        '\n\n\n\nPAOK', '\n\n\n\nFatih Karagümrük S.K.',
#        '\n\n\n\nRoyal Excel Mouscron', '\n\n\n\nRiver Plate Montevideo',
#        '\n\n\n\nAl Hilal', '\n\n\n\nEn Avant de Guingamp',
#        '\n\n\n\nPachuca', '\n\n\n\nSampdoria',
#        '\n\n\n\nFC Admira Wacker Mödling',
#        '\n\n\n\nShijiazhuang Ever Bright F.C.',
#        '\n\n\n\nEintracht Frankfurt', '\n\n\n\nJunior FC',
#        '\n\n\n\nBoavista FC', '\n\n\n\nReal Zaragoza',
#        '\n\n\n\nHammarby IF', '\n\n\n\nIpswich Town', '\n\n\n\nNapoli',
#        '\n\n\n\nKAA Gent', '\n\n\n\nRoyal Antwerp FC',
#        '\n\n\n\nSydney FC', '\n\n\n\nGuangzhou R&F FC', '\n\n\n\nVitesse',
#        '\n\n\n\nAl Ittihad', '\n\n\n\nWolverhampton Wanderers',
#        '\n\n\n\nNagoya Grampus', '\n\n\n\nAdelaide United',
#        '\n\n\n\nStevenage', '\n\n\n\nFC Nordsjælland',
#        '\n\n\n\nAS Monaco', '\n\n\n\nWalsall', '\n\n\n\nMansfield Town',
#        '\n\n\n\nSC Braga', '\n\n\n\nBrøndby IF', '\n\n\n\nWatford',
#        '\n\n\n\nRoss County FC', '\n\n\n\nBurnley', '\n\n\n\nAston Villa',
#        '\n\n\n\nClub Tijuana', '\n\n\n\nFleetwood Town',
#        '\n\n\n\nViktoria Plzeň', '\n\n\n\nPau FC', '\n\n\n\nMalmö FF',
#        '\n\n\n\nQuerétaro', '\n\n\n\nGençlerbirliği SK',
#        '\n\n\n\nLincoln City', '\n\n\n\nRC Celta', '\n\n\n\nKAS Eupen',
#        '\n\n\n\nShandong Luneng TaiShan FC', '\n\n\n\nAIK',
#        '\n\n\n\nLos Angeles FC', '\n\n\n\nStoke City',
#        '\n\n\n\nAtlanta United', '\n\n\n\nColorado Rapids',
#        '\n\n\n\nSan Jose Earthquakes', '\n\n\n\nQueens Park Rangers',
#        '\n\n\n\nMacarthur FC', '\n\n\n\nSouthampton',
#        '\n\n\n\nShanghai Greenland Shenhua FC', '\n\n\n\nWisła Kraków',
#        '\n\n\n\nFC Hermannstadt', '\n\n\n\nNewcastle Jets',
#        '\n\n\n\nKaizer Chiefs', '\n\n\n\nLa Berrichonne de Châteauroux',
#        '\n\n\n\nBarrow', '\n\n\n\nIK Start', '\n\n\n\nVélez Sarsfield',
#        '\n\n\n\nAC Monza', '\n\n\n\nAl Nassr', '\n\n\n\nOldham Athletic',
#        '\n\n\n\nAl Taawoun', '\n\n\n\nPatronato',
#        '\n\n\n\nRayo Vallecano', '\n\n\n\nSuwon Samsung Bluewings',
#        '\n\n\n\nFC Seoul', '\n\n\n\nPohang Steelers',
#        '\n\n\n\nColumbus Crew SC', '\n\n\n\nMotherwell',
#        '\n\n\n\nNorthampton Town', '\n\n\n\nSandefjord Fotball',
#        '\n\n\n\nVfB Stuttgart', '\n\n\n\nFC Bayern München',
#        '\n\n\n\nUniversidad Católica del Ecuador', '\n\n\n\nInter Miami',
#        '\n\n\n\nDC United', '\n\n\n\nSwindon Town', '\n\n\n\nSL Benfica',
#        '\n\n\n\nQingdao Huanghai F.C.', '\n\n\n\nAlianza Lima',
#        '\n\n\n\nAZ Alkmaar', '\n\n\n\nJiangsu Suning FC',
#        '\n\n\n\nStade Malherbe Caen', '\n\n\n\nCFR Cluj',
#        '\n\n\n\nWillem II', '\n\n\n\nBeijing Sinobo Guoan FC',
#        '\n\n\n\nShonan Bellmare', '\n\n\n\nFK Austria Wien',
#        '\n\n\n\nCE Sabadell FC', '\n\n\n\nSPAL',
#        '\n\n\n\nEintracht Braunschweig', '\n\n\n\nClub Atlas',
#        '\n\n\n\nMelbourne City FC', '\n\n\n\nLivingston FC',
#        '\n\n\n\nAccrington Stanley', '\n\n\n\nWest Bromwich Albion',
#        '\n\n\n\nHibernian', '\n\n\n\nSanta Clara', '\n\n\n\nExeter City',
#        '\n\n\n\nTianjin TEDA FC', '\n\n\n\nBarcelona Sporting Club',
#        '\n\n\n\nLA Galaxy', '\n\n\n\nStrømsgodset IF',
#        '\n\n\n\nUniversidad Católica', '\n\n\n\nBSC Young Boys',
#        '\n\n\n\nSint-Truidense VV', '\n\n\n\nReal Oviedo',
#        '\n\n\n\nEttifaq FC', '\n\n\n\nUD Las Palmas',
#        '\n\n\n\nUD Logroñés', '\n\n\n\nNew England Revolution',
#        '\n\n\n\nDalian YiFang FC', '\n\n\n\nSt. Mirren',
#        '\n\n\n\nNacional de Montevideo', '\n\n\n\nRiver Plate Asunción',
#        '\n\n\n\nPortland Timbers', '\n\n\n\nDeportivo Alavés',
#        '\n\n\n\nLevante UD', '\n\n\n\nAD Alcorcón',
#        '\n\n\n\nCardiff City', '\n\n\n\nMjällby AIF',
#        '\n\n\n\nValencia CF', '\n\n\n\nLyngby BK', '\n\n\n\nEverton',
#        '\n\n\n\nOs Belenenses', '\n\n\n\nBournemouth', '\n\n\n\nLecce',
#        '\n\n\n\nSV Werder Bremen', '\n\n\n\nArsenal',
#        '\n\n\n\nSheffield Wednesday', '\n\n\n\nMorecambe',
#        '\n\n\n\nLe Havre AC', '\n\n\n\nBrescia',
#        '\n\n\n\nCentral Córdoba', '\n\n\n\nClub Brugge KV',
#        '\n\n\n\nAtlético de San Luis', '\n\n\n\nTSV Hartberg',
#        '\n\n\n\nReading', '\n\n\n\nCoventry City',
#        '\n\n\n\nDundee United', '\n\n\n\nBorussia Dortmund',
#        '\n\n\n\nFC Voluntari', '\n\n\n\nCarlisle United',
#        '\n\n\n\nOxford United', '\n\n\n\nNacional Asunción',
#        '\n\n\n\nClub Blooming', '\n\n\n\nIndependiente del Valle',
#        '\n\n\n\nHouston Dynamo', '\n\n\n\nFulham', '\n\n\n\nSD Eibar',
#        '\n\n\n\nClub Bolívar', '\n\n\n\nFC Lausanne-Sport',
#        '\n\n\n\nSarpsborg 08 FF', '\n\n\n\nHatayspor',
#        '\n\n\n\nMinnesota United FC', '\n\n\n\nChicago Fire',
#        '\n\n\n\nNashville SC', '\n\n\n\nFC Cincinnati',
#        '\n\n\n\nSporting Kansas City', '\n\n\n\nGwangJu FC',
#        '\n\n\n\nKawasaki Frontale', '\n\n\n\nAlways Ready',
#        '\n\n\n\nAEK Athens', '\n\n\n\nClub Guaraní',
#        '\n\n\n\nClub Atlético Colón', '\n\n\n\nCentro Atlético Fénix',
#        '\n\n\n\nSSV Jahn Regensburg', '\n\n\n\nIndependiente Medellín',
#        '\n\n\n\nAmérica de Cali', '\n\n\n\nFC Metz',
#        '\n\n\n\nSV Wehen Wiesbaden', '\n\n\n\nFalkenbergs FF',
#        '\n\n\n\nKalmar FF', '\n\n\n\nBirmingham City',
#        '\n\n\n\nGöztepe SK', '\n\n\n\nAmiens SC',
#        '\n\n\n\nFortuna Düsseldorf', '\n\n\n\nPhiladelphia Union',
#        '\n\n\n\nBayern München II', '\n\n\n\nLDU Quito',
#        '\n\n\n\nSeattle Sounders FC', '\n\n\n\nBayer 04 Leverkusen',
#        '\n\n\n\nStade Brestois 29', '\n\n\n\nAC Ajaccio',
#        '\n\n\n\n1. FC Nürnberg', '\n\n\n\nSV Meppen', '\n\n\n\nUdinese',
#        '\n\n\n\nNewport County', '\n\n\n\nGetafe CF',
#        '\n\n\n\nLeeds United', '\n\n\n\nClub León',
#        '\n\n\n\nHellas Verona', '\n\n\n\nNîmes Olympique',
#        '\n\n\n\nSporting CP', '\n\n\n\nVVV-Venlo', '\n\n\n\nADO Den Haag',
#        '\n\n\n\nAl Raed', '\n\n\n\nHenan Jianye FC', '\n\n\n\nFC Twente',
#        '\n\n\n\nMonterrey', '\n\n\n\nC.D. Castellón',
#        '\n\n\n\nOdense Boldklub', '\n\n\n\nAl Shabab', '\n\n\n\nAl Ahli',
#        '\n\n\n\nDinamo Zagreb', '\n\n\n\nPodbeskidzie Bielsko-Biała',
#        '\n\n\n\nPeterborough United', '\n\n\n\nAarhus GF',
#        '\n\n\n\nClub Necaxa', '\n\n\n\nPuebla FC',
#        '\n\n\n\nOrlando Pirates', '\n\n\n\nDaegu FC',
#        '\n\n\n\nFC Würzburger Kickers', '\n\n\n\nRanders FC',
#        '\n\n\n\nChongqing Dangdai Lifan FC SWM Team',
#        '\n\n\n\nOlympique Lyonnais', '\n\n\n\nRC Strasbourg Alsace',
#        '\n\n\n\nAl Fayha', '\n\n\n\nSK Slavia Praha',
#        '\n\n\n\nBrighton & Hove Albion', '\n\n\n\nMelbourne Victory',
#        '\n\n\n\nÖrebro SK', '\n\n\n\n1. FC Kaiserslautern',
#        '\n\n\n\nFC Augsburg', '\n\n\n\nSparta Praha', '\n\n\n\nKRC Genk',
#        '\n\n\n\nAJ Auxerre', '\n\n\n\nShelbourne FC',
#        '\n\n\n\nHebei China Fortune FC', '\n\n\n\n1. FC Köln',
#        '\n\n\n\nFC Erzgebirge Aue', '\n\n\n\nKarlsruher SC',
#        '\n\n\n\nSpVgg Greuther Fürth', '\n\n\n\nNewcastle United',
#        '\n\n\n\nEmelec', '\n\n\n\nCentral Coast Mariners',
#        '\n\n\n\nFC Basel 1893', '\n\n\n\nJagiellonia Białystok',
#        '\n\n\n\nRaków Częstochowa', '\n\n\n\nKSV Cercle Brugge',
#        '\n\n\n\nDeportivo Cali', '\n\n\n\nHolstein Kiel',
#        '\n\n\n\nWaasland-Beveren', '\n\n\n\n1. FC Saarbrücken',
#        '\n\n\n\nMiddlesbrough', '\n\n\n\nStabæk Fotball',
#        '\n\n\n\nSC Heerenveen', '\n\n\n\n1. FC Heidenheim 1846',
#        '\n\n\n\nSC Freiburg', '\n\n\n\nVfL Bochum 1848',
#        '\n\n\n\nKFC Uerdingen 05', '\n\n\n\nFC Vaduz',
#        '\n\n\n\nReal Valladolid CF', '\n\n\n\nTSV 1860 München',
#        '\n\n\n\nAS Nancy Lorraine', '\n\n\n\nDjurgårdens IF',
#        '\n\n\n\nNew York City FC', '\n\n\n\nParis Saint-Germain',
#        '\n\n\n\nMjøndalen IF', '\n\n\n\nValenciennes FC',
#        '\n\n\n\nGrenoble Foot 38', '\n\n\n\nMálaga CF',
#        '\n\n\n\nShanghai SIPG FC', '\n\n\n\nFC Zürich',
#        '\n\n\n\nDinamo Bucureşti', '\n\n\n\nZagłębie Lubin',
#        '\n\n\n\nVejle Boldklub', '\n\n\n\nMoreirense FC',
#        '\n\n\n\nBrentford', '\n\n\n\nBlackpool', '\n\n\n\nFC Nantes',
#        '\n\n\n\n1. FSV Mainz 05', '\n\n\n\nJorge Wilstermann',
#        '\n\n\n\nGangwon FC', '\n\n\n\nPanathinaikos FC',
#        '\n\n\n\nMKE Ankaragücü', '\n\n\n\nStal Mielec',
#        '\n\n\n\nSparta Rotterdam', '\n\n\n\nSport Huancayo',
#        '\n\n\n\nLech Poznań', '\n\n\n\nLechia Gdańsk',
#        '\n\n\n\nGillingham', '\n\n\n\nRodez Aveyron Football',
#        '\n\n\n\nFeyenoord', '\n\n\n\nDeportivo Pasto',
#        '\n\n\n\nHeracles Almelo', '\n\n\n\nGirona FC',
#        '\n\n\n\nChievo Verona', '\n\n\n\nHull City',
#        '\n\n\n\nForest Green Rovers', '\n\n\n\nIndependiente',
#        '\n\n\n\nServette FC', '\n\n\n\nFC Emmen',
#        '\n\n\n\nIFK Norrköping', '\n\n\n\nSantos Laguna',
#        '\n\n\n\nSagan Tosu', '\n\n\n\nSK Sturm Graz', '\n\n\n\nCracovia',
#        '\n\n\n\nDijon FCO', '\n\n\n\nVegalta Sendai', '\n\n\n\nAl Hazem',
#        '\n\n\n\nHamilton Academical FC', '\n\n\n\nSC Verl',
#        '\n\n\n\nClub Plaza Colonia', '\n\n\n\nFC St. Gallen',
#        '\n\n\n\nVfL Wolfsburg', '\n\n\n\nWellington Phoenix',
#        '\n\n\n\nVfB Lübeck', '\n\n\n\nDelfín SC',
#        '\n\n\n\nTürkgücü München', '\n\n\n\nKasimpaşa SK',
#        '\n\n\n\nSV Ried', '\n\n\n\nPEC Zwolle', '\n\n\n\nAudax Italiano',
#        '\n\n\n\nAFC Wimbledon', '\n\n\n\nAl Adalah', '\n\n\n\nFC Tokyo',
#        '\n\n\n\nScunthorpe United', '\n\n\n\nAlbacete BP',
#        '\n\n\n\nToulouse Football Club', '\n\n\n\nEl Nacional',
#        '\n\n\n\nBarnsley', '\n\n\n\nSV Darmstadt 98',
#        '\n\n\n\nVancouver Whitecaps FC', '\n\n\n\nUD Almería',
#        '\n\n\n\nCD Nacional', '\n\n\n\nSanfrecce Hiroshima',
#        '\n\n\n\nNew York Red Bulls', '\n\n\n\nFC Ingolstadt 04',
#        '\n\n\n\nGamba Osaka', '\n\n\n\nAbha Club',
#        '\n\n\n\nKashiwa Reysol', '\n\n\n\nIncheon United FC',
#        '\n\n\n\nAl Wehda', '\n\n\n\nStade de Reims',
#        '\n\n\n\nShimizu S-Pulse', '\n\n\n\nFC Viitorul',
#        '\n\n\n\nIK Sirius', '\n\n\n\nPSV', '\n\n\n\nFC St. Pauli',
#        '\n\n\n\nAC Mineros de Guayana', '\n\n\n\nSepsi OSK',
#        '\n\n\n\nPortsmouth', '\n\n\n\nDSC Arminia Bielefeld',
#        '\n\n\n\nAcademica Clinceni', '\n\n\n\nESTAC Troyes',
#        '\n\n\n\nFortuna Sittard', '\n\n\n\nCD Tondela',
#        '\n\n\n\nFCSB (Steaua)', '\n\n\n\nUTA Arad', '\n\n\n\nAalborg BK',
#        '\n\n\n\nSligo Rovers', '\n\n\n\nCusco FC',
#        '\n\n\n\nFC Sochaux-Montbéliard', '\n\n\n\nClube Sport Marítimo',
#        '\n\n\n\nHallescher FC', '\n\n\n\nAl Ain FC',
#        '\n\n\n\nNacional Potosí', '\n\n\n\nPogoń Szczecin',
#        '\n\n\n\nUSL Dunkerque', '\n\n\n\nUnión La Calera',
#        '\n\n\n\nEmpoli', '\n\n\n\nBohemian FC', '\n\n\n\nCD Mirandés',
#        '\n\n\n\nFinn Harps', '\n\n\n\nAl Fateh', '\n\n\n\nSol de América',
#        '\n\n\n\nTrabzonspor', '\n\n\n\nChindia Târgovişte',
#        '\n\n\n\nSportivo Luqueño', '\n\n\n\nAl Faisaly',
#        '\n\n\n\nClermont Foot 63', '\n\n\n\nFC Hansa Rostock',
#        '\n\n\n\nCerezo Osaka', '\n\n\n\nVarbergs BoIS',
#        '\n\n\n\nChamois Niortais Football Club',
#        '\n\n\n\nSG Dynamo Dresden', '\n\n\n\nRSC Anderlecht',
#        '\n\n\n\nSKN St. Pölten', '\n\n\n\nGodoy Cruz', '\n\n\n\nFarense',
#        '\n\n\n\nDeportivo Binacional', '\n\n\n\nÖstersunds FK',
#        '\n\n\n\nEstudiantes de Mérida', '\n\n\n\nFK Bodø/Glimt',
#        '\n\n\n\nYokohama F. Marinos', '\n\n\n\nLiverpool Fútbol Club',
#        '\n\n\n\nDynamo Kyiv', '\n\n\n\nCD Huachipato',
#        '\n\n\n\nSangju Sangmu FC', '\n\n\n\nDamac FC',
#        '\n\n\n\nCaracas FC', '\n\n\n\nSV Waldhof Mannheim',
#        '\n\n\n\nUnión de Santa Fe', '\n\n\n\nZamora FC',
#        '\n\n\n\nMillonarios FC', '\n\n\n\nAtlético Nacional',
#        '\n\n\n\nDefensa y Justicia', '\n\n\n\nClub Atlético Grau',
#        '\n\n\n\nGórnik Zabrze', '\n\n\n\nFamalicão', '\n\n\n\nFortaleza',
#        '\n\n\n\nBahia', '\n\n\n\nOceânico FC', '\n\n\n\nGrêmio',
#        '\n\n\n\nCeará Sporting Club', '\n\n\n\nCoritiba', '\n\n\n\nGoiás',
#        '\n\n\n\nAtlético Mineiro', '\n\n\n\nSão Paulo',
#        '\n\n\n\nVasco da Gama', '\n\n\n\nPalmeiras',
#        '\n\n\n\nInternacional', '\n\n\n\nFlamengo',
#        '\n\n\n\nClub Athletico Paranaense', '\n\n\n\nFluminense',
#        '\n\n\n\nBotafogo', '\n\n\n\nSantos',
#        '\n\n\n\nAtlético Clube Goianiense', '\n\n\n\nOita Trinita',
#        '\n\n\n\nAragua FC', '\n\n\n\nLlaneros de Guanare'], dtype=object)

# %%
df['Club'] = df['Club'].str.replace('\n', '')
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\1001944083.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = df['Club'].str.replace('\n', '')

# %%
df['Club'].unique()
# Out:
# array(['Vissel Kobe', 'Juventus', 'Ajax', 'Rio Ave FC', 'SD Ponferradina',
#        'FC Groningen', 'Crewe Alexandra', 'Gil Vicente FC',
#        'Sporting de Charleroi', 'Crawley Town', 'Vitória Guimarães',
#        'Lazio', 'Olimpia Asunción', 'Yokohama FC', 'Real Salt Lake',
#        'Milan', 'Real Betis', 'IFK Göteborg', 'San Lorenzo de Almagro',
#        'Rangers FC', 'SV Zulte-Waregem', 'Angers SCO', 'KV Mechelen',
#        'Tranmere Rovers', 'SK Brann', 'Bristol City', 'Leicester City',
#        'FC Lugano', 'Hokkaido Consadole Sapporo', 'Leyton Orient',
#        'Manchester United', 'Rotherham United', 'Wycombe Wanderers',
#        'Sheffield United', 'Grimsby Town', 'Derby County', 'Swansea City',
#        'Hannover 96', 'Spezia', 'Hertha BSC', 'Kilmarnock',
#        'FK Haugesund', 'SpVgg Unterhaching', 'Standard de Liège',
#        'Legia Warszawa', 'Sassuolo', 'FC Schalke 04',
#        'Olympique de Marseille', 'FC Dallas', 'KV Oostende',
#        "Newell's Old Boys", 'Shamrock Rovers', 'Real Sociedad',
#        'CD Leganés', 'Plymouth Argyle', 'Coquimbo Unido', 'Elche CF',
#        'FC Cartagena', 'Montreal Impact', 'West Ham United',
#        'Salford City', 'FC Chambly Oise', 'Benevento',
#        'Nottingham Forest', 'FC Porto', 'FC Red Bull Salzburg',
#        'FSV Zwickau', 'SV Sandhausen', 'Sivasspor', 'LOSC Lille',
#        'Denizlispor', 'Medipol Başakşehir FK', 'Antalyaspor',
#        'FC København', 'Yeni Malatyaspor', 'Çaykur Rizespor',
#        'Alanyaspor', 'Rochdale', 'FC Midtjylland', 'No Club',
#        'Beşiktaş JK', 'FC Girondins de Bordeaux', 'Celtic',
#        'Helsingborgs IF', 'Wolfsberger AC', 'Manchester City',
#        'Jeonbuk Hyundai Motors', 'Seongnam FC', 'KV Kortrijk',
#        '1. FC Magdeburg', 'Wuhan Zall', 'Genoa', 'Parma', 'Liverpool',
#        'River Plate', 'Milton Keynes Dons', 'Chelsea', 'Orlando City SC',
#        'Western Sydney Wanderers', 'Preston North End', 'Harrogate Town',
#        'Colchester United', 'St. Johnstone FC', 'Argentinos Juniors',
#        'FC Lorient', 'Kashima Antlers', 'Club Libertad', 'Club América',
#        'Roma', 'Derry City', 'Waterford FC', 'Bolton Wanderers',
#        'Burton Albion', 'Doncaster Rovers', 'Cagliari', 'WSG Tirol',
#        'Peñarol', 'Cork City', 'CD Tenerife', 'Racing Club',
#        'Estudiantes de La Plata', 'Rosario Central',
#        'Club Atlético Banfield', 'Shakhtar Donetsk',
#        'Club Atlético Talleres', 'Club Atlético Tigre', 'Boca Juniors',
#        'Arsenal de Sarandí', 'Atalanta', 'Fenerbahçe SK',
#        'Club Atlético Lanús', 'Club Atlético Aldosivi', 'Galatasaray SK',
#        'Gazişehir Gaziantep F.K.', 'FC Luzern', 'Viktoria Köln',
#        'Atiker Konyaspor', 'Borussia Mönchengladbach', 'Perth Glory',
#        'CD Lugo', 'SD Huesca', 'Cádiz CF', 'Real Sporting de Gijón',
#        'Sevilla FC', 'HJK Helsinki', 'RCD Espanyol', 'Granada CF',
#        'Athletic Club de Bilbao', 'CA Osasuna', 'Politehnica Iaşi',
#        'Universitatea Craiova', 'Gaz Metan Mediaş', 'FC Argeș',
#        'PFC CSKA Moscow', 'Spartak Moscow', 'FC Paços de Ferreira',
#        'Odds BK', 'Viking FK', 'Crotone', 'Torino', 'Dundalk',
#        'Cambridge United', 'Olympiacos CFP', 'Stade Rennais FC',
#        'Oud-Heverlee Leuven', 'Paris FC', 'Tottenham Hotspur',
#        'Lokomotiv Moscow', 'Beerschot AC', 'SønderjyskE', 'SCR Altach',
#        'Bradford City', 'Port Vale', 'Molde FK', 'Southend United',
#        'Cheltenham Town', 'Blackburn Rovers', 'Norwich City',
#        'Vålerenga Fotball', 'Portimonense SC', 'FC Barcelona',
#        'Kayserispor', 'Inter', 'Deportivo Toluca', 'Śląsk Wrocław',
#        'Club Atlético Huracán', 'Rosenborg BK', 'Bologna', 'Aalesunds FK',
#        'Colo-Colo', 'SD Aucas', 'Gimnasia y Esgrima La Plata',
#        'Melgar FBC', 'Tigres U.A.N.L.', 'Montpellier HSC',
#        'Racing Club de Lens', 'FC Botoşani', 'Kristiansund BK',
#        'Busan IPark', 'Ulsan Hyundai FC', 'Piast Gliwice',
#        'Astra Giurgiu', 'Huddersfield Town', 'Shrewsbury', 'AC Horsens',
#        'Warta Poznań', 'Real Madrid', 'Millwall', 'Sunderland',
#        'Crystal Palace', 'Toronto FC', 'Brisbane Roar', 'Aberdeen',
#        'Luton Town', 'Wisła Płock', 'RKC Waalwijk', 'Cruz Azul',
#        'FC Sion', 'U.N.A.M.', 'TSG 1899 Hoffenheim', 'LASK Linz',
#        'Urawa Red Diamonds', 'Atlético Tucumán', 'FC Juárez',
#        'Atlético Madrid', 'Fiorentina', 'BB Erzurumspor', 'IF Elfsborg',
#        'Charlton Athletic', 'BK Häcken', "St. Patrick's Athletic",
#        'Villarreal CF', 'Mazatlán FC', 'MSV Duisburg', 'SC Paderborn 07',
#        'Western United FC', 'Bristol Rovers', 'Hamburger SV',
#        'RCD Mallorca', 'SK Rapid Wien', 'CF Fuenlabrada',
#        'Guangzhou Evergrande Taobao FC', 'Shenzhen FC', 'VfL Osnabrück',
#        'Guadalajara', 'OGC Nice', 'AS Saint-Étienne', 'RB Leipzig',
#        'FC Utrecht', 'Oriente Petrolero', '1. FC Union Berlin',
#        'Wigan Athletic', 'PAOK', 'Fatih Karagümrük S.K.',
#        'Royal Excel Mouscron', 'River Plate Montevideo', 'Al Hilal',
#        'En Avant de Guingamp', 'Pachuca', 'Sampdoria',
#        'FC Admira Wacker Mödling', 'Shijiazhuang Ever Bright F.C.',
#        'Eintracht Frankfurt', 'Junior FC', 'Boavista FC', 'Real Zaragoza',
#        'Hammarby IF', 'Ipswich Town', 'Napoli', 'KAA Gent',
#        'Royal Antwerp FC', 'Sydney FC', 'Guangzhou R&F FC', 'Vitesse',
#        'Al Ittihad', 'Wolverhampton Wanderers', 'Nagoya Grampus',
#        'Adelaide United', 'Stevenage', 'FC Nordsjælland', 'AS Monaco',
#        'Walsall', 'Mansfield Town', 'SC Braga', 'Brøndby IF', 'Watford',
#        'Ross County FC', 'Burnley', 'Aston Villa', 'Club Tijuana',
#        'Fleetwood Town', 'Viktoria Plzeň', 'Pau FC', 'Malmö FF',
#        'Querétaro', 'Gençlerbirliği SK', 'Lincoln City', 'RC Celta',
#        'KAS Eupen', 'Shandong Luneng TaiShan FC', 'AIK', 'Los Angeles FC',
#        'Stoke City', 'Atlanta United', 'Colorado Rapids',
#        'San Jose Earthquakes', 'Queens Park Rangers', 'Macarthur FC',
#        'Southampton', 'Shanghai Greenland Shenhua FC', 'Wisła Kraków',
#        'FC Hermannstadt', 'Newcastle Jets', 'Kaizer Chiefs',
#        'La Berrichonne de Châteauroux', 'Barrow', 'IK Start',
#        'Vélez Sarsfield', 'AC Monza', 'Al Nassr', 'Oldham Athletic',
#        'Al Taawoun', 'Patronato', 'Rayo Vallecano',
#        'Suwon Samsung Bluewings', 'FC Seoul', 'Pohang Steelers',
#        'Columbus Crew SC', 'Motherwell', 'Northampton Town',
#        'Sandefjord Fotball', 'VfB Stuttgart', 'FC Bayern München',
#        'Universidad Católica del Ecuador', 'Inter Miami', 'DC United',
#        'Swindon Town', 'SL Benfica', 'Qingdao Huanghai F.C.',
#        'Alianza Lima', 'AZ Alkmaar', 'Jiangsu Suning FC',
#        'Stade Malherbe Caen', 'CFR Cluj', 'Willem II',
#        'Beijing Sinobo Guoan FC', 'Shonan Bellmare', 'FK Austria Wien',
#        'CE Sabadell FC', 'SPAL', 'Eintracht Braunschweig', 'Club Atlas',
#        'Melbourne City FC', 'Livingston FC', 'Accrington Stanley',
#        'West Bromwich Albion', 'Hibernian', 'Santa Clara', 'Exeter City',
#        'Tianjin TEDA FC', 'Barcelona Sporting Club', 'LA Galaxy',
#        'Strømsgodset IF', 'Universidad Católica', 'BSC Young Boys',
#        'Sint-Truidense VV', 'Real Oviedo', 'Ettifaq FC', 'UD Las Palmas',
#        'UD Logroñés', 'New England Revolution', 'Dalian YiFang FC',
#        'St. Mirren', 'Nacional de Montevideo', 'River Plate Asunción',
#        'Portland Timbers', 'Deportivo Alavés', 'Levante UD',
#        'AD Alcorcón', 'Cardiff City', 'Mjällby AIF', 'Valencia CF',
#        'Lyngby BK', 'Everton', 'Os Belenenses', 'Bournemouth', 'Lecce',
#        'SV Werder Bremen', 'Arsenal', 'Sheffield Wednesday', 'Morecambe',
#        'Le Havre AC', 'Brescia', 'Central Córdoba', 'Club Brugge KV',
#        'Atlético de San Luis', 'TSV Hartberg', 'Reading', 'Coventry City',
#        'Dundee United', 'Borussia Dortmund', 'FC Voluntari',
#        'Carlisle United', 'Oxford United', 'Nacional Asunción',
#        'Club Blooming', 'Independiente del Valle', 'Houston Dynamo',
#        'Fulham', 'SD Eibar', 'Club Bolívar', 'FC Lausanne-Sport',
#        'Sarpsborg 08 FF', 'Hatayspor', 'Minnesota United FC',
#        'Chicago Fire', 'Nashville SC', 'FC Cincinnati',
#        'Sporting Kansas City', 'GwangJu FC', 'Kawasaki Frontale',
#        'Always Ready', 'AEK Athens', 'Club Guaraní',
#        'Club Atlético Colón', 'Centro Atlético Fénix',
#        'SSV Jahn Regensburg', 'Independiente Medellín', 'América de Cali',
#        'FC Metz', 'SV Wehen Wiesbaden', 'Falkenbergs FF', 'Kalmar FF',
#        'Birmingham City', 'Göztepe SK', 'Amiens SC', 'Fortuna Düsseldorf',
#        'Philadelphia Union', 'Bayern München II', 'LDU Quito',
#        'Seattle Sounders FC', 'Bayer 04 Leverkusen', 'Stade Brestois 29',
#        'AC Ajaccio', '1. FC Nürnberg', 'SV Meppen', 'Udinese',
#        'Newport County', 'Getafe CF', 'Leeds United', 'Club León',
#        'Hellas Verona', 'Nîmes Olympique', 'Sporting CP', 'VVV-Venlo',
#        'ADO Den Haag', 'Al Raed', 'Henan Jianye FC', 'FC Twente',
#        'Monterrey', 'C.D. Castellón', 'Odense Boldklub', 'Al Shabab',
#        'Al Ahli', 'Dinamo Zagreb', 'Podbeskidzie Bielsko-Biała',
#        'Peterborough United', 'Aarhus GF', 'Club Necaxa', 'Puebla FC',
#        'Orlando Pirates', 'Daegu FC', 'FC Würzburger Kickers',
#        'Randers FC', 'Chongqing Dangdai Lifan FC SWM Team',
#        'Olympique Lyonnais', 'RC Strasbourg Alsace', 'Al Fayha',
#        'SK Slavia Praha', 'Brighton & Hove Albion', 'Melbourne Victory',
#        'Örebro SK', '1. FC Kaiserslautern', 'FC Augsburg', 'Sparta Praha',
#        'KRC Genk', 'AJ Auxerre', 'Shelbourne FC',
#        'Hebei China Fortune FC', '1. FC Köln', 'FC Erzgebirge Aue',
#        'Karlsruher SC', 'SpVgg Greuther Fürth', 'Newcastle United',
#        'Emelec', 'Central Coast Mariners', 'FC Basel 1893',
#        'Jagiellonia Białystok', 'Raków Częstochowa', 'KSV Cercle Brugge',
#        'Deportivo Cali', 'Holstein Kiel', 'Waasland-Beveren',
#        '1. FC Saarbrücken', 'Middlesbrough', 'Stabæk Fotball',
#        'SC Heerenveen', '1. FC Heidenheim 1846', 'SC Freiburg',
#        'VfL Bochum 1848', 'KFC Uerdingen 05', 'FC Vaduz',
#        'Real Valladolid CF', 'TSV 1860 München', 'AS Nancy Lorraine',
#        'Djurgårdens IF', 'New York City FC', 'Paris Saint-Germain',
#        'Mjøndalen IF', 'Valenciennes FC', 'Grenoble Foot 38', 'Málaga CF',
#        'Shanghai SIPG FC', 'FC Zürich', 'Dinamo Bucureşti',
#        'Zagłębie Lubin', 'Vejle Boldklub', 'Moreirense FC', 'Brentford',
#        'Blackpool', 'FC Nantes', '1. FSV Mainz 05', 'Jorge Wilstermann',
#        'Gangwon FC', 'Panathinaikos FC', 'MKE Ankaragücü', 'Stal Mielec',
#        'Sparta Rotterdam', 'Sport Huancayo', 'Lech Poznań',
#        'Lechia Gdańsk', 'Gillingham', 'Rodez Aveyron Football',
#        'Feyenoord', 'Deportivo Pasto', 'Heracles Almelo', 'Girona FC',
#        'Chievo Verona', 'Hull City', 'Forest Green Rovers',
#        'Independiente', 'Servette FC', 'FC Emmen', 'IFK Norrköping',
#        'Santos Laguna', 'Sagan Tosu', 'SK Sturm Graz', 'Cracovia',
#        'Dijon FCO', 'Vegalta Sendai', 'Al Hazem',
#        'Hamilton Academical FC', 'SC Verl', 'Club Plaza Colonia',
#        'FC St. Gallen', 'VfL Wolfsburg', 'Wellington Phoenix',
#        'VfB Lübeck', 'Delfín SC', 'Türkgücü München', 'Kasimpaşa SK',
#        'SV Ried', 'PEC Zwolle', 'Audax Italiano', 'AFC Wimbledon',
#        'Al Adalah', 'FC Tokyo', 'Scunthorpe United', 'Albacete BP',
#        'Toulouse Football Club', 'El Nacional', 'Barnsley',
#        'SV Darmstadt 98', 'Vancouver Whitecaps FC', 'UD Almería',
#        'CD Nacional', 'Sanfrecce Hiroshima', 'New York Red Bulls',
#        'FC Ingolstadt 04', 'Gamba Osaka', 'Abha Club', 'Kashiwa Reysol',
#        'Incheon United FC', 'Al Wehda', 'Stade de Reims',
#        'Shimizu S-Pulse', 'FC Viitorul', 'IK Sirius', 'PSV',
#        'FC St. Pauli', 'AC Mineros de Guayana', 'Sepsi OSK', 'Portsmouth',
#        'DSC Arminia Bielefeld', 'Academica Clinceni', 'ESTAC Troyes',
#        'Fortuna Sittard', 'CD Tondela', 'FCSB (Steaua)', 'UTA Arad',
#        'Aalborg BK', 'Sligo Rovers', 'Cusco FC', 'FC Sochaux-Montbéliard',
#        'Clube Sport Marítimo', 'Hallescher FC', 'Al Ain FC',
#        'Nacional Potosí', 'Pogoń Szczecin', 'USL Dunkerque',
#        'Unión La Calera', 'Empoli', 'Bohemian FC', 'CD Mirandés',
#        'Finn Harps', 'Al Fateh', 'Sol de América', 'Trabzonspor',
#        'Chindia Târgovişte', 'Sportivo Luqueño', 'Al Faisaly',
#        'Clermont Foot 63', 'FC Hansa Rostock', 'Cerezo Osaka',
#        'Varbergs BoIS', 'Chamois Niortais Football Club',
#        'SG Dynamo Dresden', 'RSC Anderlecht', 'SKN St. Pölten',
#        'Godoy Cruz', 'Farense', 'Deportivo Binacional', 'Östersunds FK',
#        'Estudiantes de Mérida', 'FK Bodø/Glimt', 'Yokohama F. Marinos',
#        'Liverpool Fútbol Club', 'Dynamo Kyiv', 'CD Huachipato',
#        'Sangju Sangmu FC', 'Damac FC', 'Caracas FC',
#        'SV Waldhof Mannheim', 'Unión de Santa Fe', 'Zamora FC',
#        'Millonarios FC', 'Atlético Nacional', 'Defensa y Justicia',
#        'Club Atlético Grau', 'Górnik Zabrze', 'Famalicão', 'Fortaleza',
#        'Bahia', 'Oceânico FC', 'Grêmio', 'Ceará Sporting Club',
#        'Coritiba', 'Goiás', 'Atlético Mineiro', 'São Paulo',
#        'Vasco da Gama', 'Palmeiras', 'Internacional', 'Flamengo',
#        'Club Athletico Paranaense', 'Fluminense', 'Botafogo', 'Santos',
#        'Atlético Clube Goianiense', 'Oita Trinita', 'Aragua FC',
#        'Llaneros de Guanare'], dtype=object)

# %%
df.head()
# Out:
#         ID             Name               LongName  \
# 350     41          Iniesta   Andrés Iniesta Luján
# 262   1179        G. Buffon       Gianluigi Buffon
# 3348  2147  M. Stekelenburg   Maarten Stekelenburg
# 3730  3281        Tarantini  Ricardo José Monteiro
# 4207  3467             Yuri  Yuri de Souza Fonseca
#
#                                               photoUrl  \
# 350   https://cdn.sofifa.com/players/000/041/21_60.png
# 262   https://cdn.sofifa.com/players/001/179/21_60.png
# 3348  https://cdn.sofifa.com/players/002/147/21_60.png
# 3730  https://cdn.sofifa.com/players/003/281/21_60.png
# 4207  https://cdn.sofifa.com/players/003/467/21_60.png
#
#                                               playerUrl  Nationality  Age  \
# 350   http://sofifa.com/player/41/andres-iniesta-luj...        Spain   36
# 262   http://sofifa.com/player/1179/gianluigi-buffon...        Italy   42
# 3348  http://sofifa.com/player/2147/maarten-stekelen...  Netherlands   37
# 3730  http://sofifa.com/player/3281/ricardo-jose-mon...     Portugal   36
# 4207  http://sofifa.com/player/3467/yuri-de-souza-fo...       Brazil   37
#
#       ↓OVA  POT             Club  ...     A/W     D/W   IR PAC SHO  PAS DRI  \
# 350     81   81      Vissel Kobe  ...    High  Medium  4 ★  58  70   85  85
# 262     82   82         Juventus  ...  Medium  Medium  4 ★  77  76   74  78
# 3348    72   72             Ajax  ...  Medium  Medium  2 ★  69  71   72  70
# 3730    72   72       Rio Ave FC  ...  Medium  Medium  1 ★  50  67   71  70
# 4207    71   71  SD Ponferradina  ...    High  Medium  1 ★  66  74   59  69
#
#      DEF PHY Hits
# 350   63  59  130
# 262   33  91  131
# 3348  33  73   23
# 3730  70  67    4
# 4207  35  69    5
#
# [5 rows x 76 columns]

# %%
df[['Name','Positions','Best Position']]
# Out:
#                   Name    Positions Best Position
# 350            Iniesta      CM, CAM           CAM
# 262          G. Buffon           GK            GK
# 3348   M. Stekelenburg           GK            GK
# 3730         Tarantini      CM, CDM            CM
# 4207              Yuri           ST            ST
# ...                ...          ...           ...
# 15843       N. Ahamada           CM           CAM
# 12487    A. Stergiakis           GK            GK
# 12547      M. Bajamich  RW, ST, CAM            RW
# 15200       O. Özdoğan           GK            GK
# 12532        W. Jooste       RW, RM            RW
#
# [16384 rows x 3 columns]

# %%
df['Positions'].unique()
# Out:
# array(['CM, CAM', 'GK', 'CM, CDM', 'ST', 'RM, CAM', 'CB', 'RM, LM',
#        'ST, LW', 'CAM, CF, RW', 'CDM, CM', 'LM, RM', 'CM, CAM, ST',
#        'CB, LB', 'CM, CDM, LM', 'CM', 'CM, CDM, CAM', 'LM, RM, ST',
#        'RM, RW', 'LW, LM, ST', 'RWB, RM', 'ST, CF, CAM', 'LB, LM',
#        'CDM, CB', 'LB', 'ST, LM', 'CDM', 'CAM, CM', 'CB, CDM',
#        'CM, CB, CAM', 'ST, RW', 'CM, RB, LB', 'RB', 'LB, LWB', 'LW, RW',
#        'CAM, LM, CM', 'CB, RB', 'CDM, CM, CB', 'CM, RB', 'ST, CAM, CF',
#        'CAM, CF, ST', 'LM, CM', 'ST, CAM', 'RB, RM', 'LW, CAM', 'CAM, RM',
#        'CAM, RW, ST', 'RB, RWB', 'CAM', 'LM, LW', 'CAM, LM', 'LM, RM, RB',
#        'CAM, RM, LM', 'LM, CAM', 'LB, LWB, LM', 'ST, CF', 'RM',
#        'RB, ST, LM', 'CAM, RM, CM', 'LM', 'RM, CM', 'CF, LM, LW',
#        'LW, RW, ST', 'CAM, RW', 'RM, CAM, LM', 'RW, ST, CF', 'RM, ST',
#        'ST, RW, LW', 'RB, CB, RWB', 'ST, LM, CAM', 'ST, LM, LW',
#        'CAM, CDM', 'CM, CAM, CDM', 'CAM, CM, RM', 'RB, LB', 'CDM, RB, CM',
#        'LB, RB, CB', 'LM, LB, LWB', 'LB, CB', 'RM, CF, RB', 'RW, CAM',
#        'LB, RB', 'CDM, CB, CM', 'CAM, CM, CF', 'CF, ST', 'CDM, RB, RWB',
#        'RM, RW, LM', 'RM, LM, ST', 'LWB, RWB', 'CM, LB', 'RW, ST',
#        'CB, LB, RB', 'LM, ST', 'RM, LM, LB', 'CB, RB, LB', 'RW, ST, CAM',
#        'CM, CAM, LM', 'ST, CAM, CM', 'LB, LM, LWB', 'RB, CB',
#        'RW, LW, CAM', 'RB, RWB, RM', 'RM, LW', 'CM, CDM, CB', 'ST, RWB',
#        'RW, LW', 'RWB, RB', 'LWB, LB', 'RM, RB', 'CAM, ST, CF',
#        'ST, CAM, RW', 'LM, LW, ST', 'LW', 'CAM, ST', 'CM, RM',
#        'RB, RM, CM', 'RM, LM, CAM', 'RM, RWB', 'LB, CB, LM', 'LM, LB',
#        'LWB', 'CAM, RM, RW', 'RW', 'ST, CAM, LM', 'ST, RB, RM', 'CF, CM',
#        'CAM, LM, RM', 'CAM, RM, ST', 'RB, CDM', 'RM, CDM, LM',
#        'ST, LW, CAM', 'CM, LW, ST', 'LW, CF, ST', 'RM, ST, LM',
#        'CDM, CM, ST', 'RM, CAM, ST', 'CB, RWB', 'RM, RB, RW',
#        'CAM, ST, LW', 'RB, CDM, CM', 'LM, CM, RM', 'RM, RB, LB',
#        'LM, LB, RB', 'LB, CM', 'LM, RWB, RM', 'RW, CF', 'CM, LM',
#        'CM, CF', 'RB, LB, RM', 'ST, RM', 'ST, CAM, LW', 'CM, LM, RM',
#        'LWB, CM, LB', 'LM, CAM, CM', 'LWB, LM, LB', 'RWB, CAM',
#        'RW, LW, RM', 'CM, CAM, RW', 'CDM, CB, LB', 'CDM, RB',
#        'LB, LWB, CB', 'CB, CDM, CM', 'RW, RM, LM', 'LM, LW, RW',
#        'ST, LW, LM', 'CDM, CM, RM', 'LW, LM', 'LM, LWB, RM',
#        'CAM, CM, CDM', 'LW, ST', 'RM, CF, LM', 'CM, CDM, RM',
#        'CB, RB, CM', 'CDM, CM, LB', 'RM, RW, CM', 'LB, CDM',
#        'RM, RB, CAM', 'LM, LW, RM', 'RB, RM, RW', 'CAM, CDM, CM',
#        'CDM, RB, LB', 'CB, ST', 'RM, CAM, CF', 'RWB, RB, RM',
#        'RM, CM, ST', 'CAM, CF', 'RB, LB, CB', 'ST, RM, LM', 'RM, ST, RW',
#        'RM, LM, RW', 'CM, LW', 'RM, RW, CAM', 'RB, RM, RWB', 'CF, ST, LM',
#        'CM, RB, LM', 'ST, LM, RM', 'CB, LWB', 'CAM, LM, CF', 'RM, LWB',
#        'RM, ST, CAM', 'CAM, CF, CM', 'RWB, CM, RM', 'RB, LB, RWB',
#        'ST, LW, RW', 'LB, CM, RB', 'LW, ST, LM', 'CDM, LM, CM',
#        'LM, CAM, ST', 'CAM, CM, LM', 'RM, CM, CAM', 'CAM, CM, LW',
#        'CB, LB, LWB', 'LW, ST, RW', 'CAM, ST, RW', 'CM, RM, LM',
#        'RWB, CB', 'CB, RB, CDM', 'CF, LM, CAM', 'LM, ST, RM', 'CAM, LW',
#        'LM, LWB, CM', 'LM, LWB, LB', 'CAM, LW, CM', 'CM, CDM, RB',
#        'RW, RM', 'LM, RM, LW', 'LW, CAM, RW', 'LW, LM, LB', 'LB, LWB, RB',
#        'RM, RWB, LM', 'RM, LM, LW', 'CB, RB, RWB', 'CM, LM, LB',
#        'ST, CF, LM', 'RB, RW', 'CF, ST, RW', 'CF, CAM, LW', 'LM, RW, LW',
#        'CM, CF, CAM', 'RW, LM', 'LB, LM, CB', 'LM, RM, CAM', 'RM, LB, LM',
#        'CAM, RM, CF', 'CAM, ST, LM', 'RB, RWB, CB', 'CM, RM, LW',
#        'CM, RM, CAM', 'CB, CDM, LB', 'RWB, RB, LWB', 'ST, CF, LW',
#        'CAM, ST, CM', 'LM, LB, CDM', 'CF, ST, CAM', 'CM, LM, CAM',
#        'LB, CB, RB', 'CF, CAM, ST', 'LM, RM, RW', 'LW, CM', 'LWB, LM',
#        'LWB, CB', 'RWB, CM', 'CM, LWB', 'CAM, LW, LM', 'CM, CAM, RM',
#        'LM, LW, CAM', 'RM, LB, RB', 'RM, CAM, RW', 'LM, CAM, RM',
#        'CM, LB, LM', 'RB, RM, LB', 'RM, CM, LM', 'LM, RM, CM',
#        'RM, RB, LM', 'LM, RW, RM', 'LM, LB, CM', 'CM, CF, LM',
#        'CF, CAM, CM', 'CM, LWB, LM', 'CDM, RM, CM', 'LB, LM, RM',
#        'RB, CB, LB', 'CAM, RW, CM', 'LM, LW, CM', 'RW, RB, RM',
#        'CAM, CM, RW', 'RM, RWB, RB', 'LW, LWB, RWB', 'CB, CM',
#        'LB, CB, LWB', 'CDM, CM, RB', 'RB, CB, RM', 'LW, CF',
#        'ST, CAM, RM', 'RWB', 'CF, CAM', 'RM, LM, CM', 'CM, ST',
#        'CF, CAM, RW', 'LM, CF', 'LB, RB, CM', 'CM, CDM, LW',
#        'LM, ST, CAM', 'RB, CM', 'CF, CAM, LM', 'CF, LW, CAM',
#        'CM, LM, CDM', 'RWB, RM, LWB', 'RW, LM, RM', 'RM, CAM, CM',
#        'RW, RM, CAM', 'RM, LM, RWB', 'LM, CM, LB', 'RM, CF',
#        'CM, RM, CDM', 'CF, LW', 'LB, LM, LW', 'CAM, CM, ST', 'RW, ST, LW',
#        'LB, LM, RB', 'RM, RW, ST', 'RW, LW, ST', 'CAM, LW, ST',
#        'LW, CAM, CF', 'CF', 'RM, LM, LWB', 'ST, CM', 'LB, RB, RM',
#        'RW, RM, LW', 'CM, RW', 'RWB, RM, RB', 'CM, LM, RB', 'LM, RB, LB',
#        'CB, CDM, RB', 'LW, LM, CAM', 'LW, RW, LM', 'LM, CF, RM',
#        'LM, RM, CF', 'RM, LM, CF', 'CDM, CAM', 'LW, CF, LM',
#        'RB, RWB, LB', 'CAM, RW, RM', 'ST, RM, CAM', 'RM, LW, CAM',
#        'RWB, RW', 'LB, CM, LM', 'CM, RW, CAM', 'RW, LB', 'CB, RWB, RB',
#        'RB, LB, CDM', 'CAM, LM, ST', 'CAM, LM, LW', 'RW, RM, CF',
#        'ST, RW, CAM', 'LW, RW, CM', 'RW, RWB, RM', 'RB, RWB, CDM',
#        'LM, LB, RM', 'ST, RW, RM', 'LWB, LB, LM', 'CDM, CM, CAM',
#        'CB, RB, RM', 'LM, ST, LW', 'CB, CM, CDM', 'CM, CB, CDM',
#        'LW, CAM, CM', 'LM, LWB', 'CM, CAM, LB', 'RM, RW, RB',
#        'CM, CAM, LW', 'RM, CAM, RB', 'RWB, LW, LM', 'ST, RM, CF',
#        'LW, LB, LM', 'CDM, LB', 'LW, RW, CF', 'CM, RWB', 'ST, LM, RB',
#        'ST, CB, CDM', 'LB, RB, RWB', 'RB, RM, CB', 'RB, CM, CAM',
#        'CM, RW, LW', 'LW, LB', 'LM, CM, CAM', 'LWB, CM', 'LB, CDM, CB',
#        'RW, LW, CF', 'RM, RWB, ST', 'CDM, CAM, CM', 'CM, RM, RB',
#        'LWB, LB, CB', 'LM, CM, LW', 'CB, CAM, CM', 'CM, CF, RM',
#        'RB, CB, CDM', 'LM, ST, LB', 'LB, RM, RB', 'RB, CM, RWB',
#        'RB, RWB, RW', 'RWB, RW, RB', 'CM, ST, CDM', 'CF, RM, RW',
#        'LW, RM, CM', 'LM, RM, LB', 'LW, RM, CAM', 'RB, CDM, RM',
#        'CAM, ST, RM', 'CDM, CM, LM', 'CDM, RB, RM', 'RW, LWB, RM',
#        'ST, LWB', 'LWB, LM, CM', 'CM, CB', 'LM, RM, LWB', 'RW, RWB',
#        'RM, RW, CF', 'LM, CAM, LW', 'CM, LW, LM', 'CF, LW, ST',
#        'LWB, RM, LB', 'RWB, LWB', 'RW, LWB, LW', 'CDM, RB, CB',
#        'ST, RM, LW', 'CDM, CM, RWB', 'CF, LM, RM', 'RM, CM, CDM',
#        'LWB, LW, LB', 'CAM, LW, RW', 'LM, CAM, LB', 'RW, CAM, CM',
#        'RW, CAM, RM', 'RM, ST, LW', 'LWB, LB, RW', 'LB, CM, LW',
#        'ST, LM, RW', 'RM, LM, RB', 'RB, CAM', 'RM, RW, LW', 'LB, LW',
#        'CM, RM, RWB', 'CF, RM, CM', 'RB, LB, LWB', 'ST, LW, LWB',
#        'LM, CM, RW', 'LB, LM, CAM', 'CAM, CF, RM', 'CDM, LB, CM',
#        'LW, ST, CAM', 'LM, RW', 'LW, RW, CAM', 'LB, LW, RW', 'LM, CF, ST',
#        'RM, LB, CM', 'CM, RB, RM', 'CM, CDM, LB', 'CDM, CB, RB',
#        'RB, CM, RM', 'RB, CM, LB', 'RW, LW, RWB', 'CM, RM, RW',
#        'LW, LM, CF', 'RW, CM', 'LW, ST, CM', 'RM, CM, RB', 'CAM, CF, LM',
#        'RW, CM, CAM', 'CF, ST, LW', 'RW, LW, LM', 'RB, RW, LB',
#        'CDM, RM, RB', 'LWB, LW', 'LM, LWB, ST', 'LM, LW, LB',
#        'LW, RW, RM', 'RW, ST, RM', 'CM, RM, ST', 'LW, CAM, ST',
#        'LM, LB, LW', 'CAM, CDM, LM', 'LM, ST, RW', 'RB, CB, ST',
#        'RWB, RB, CB', 'CB, RW', 'RW, RB', 'CAM, RW, LW', 'LM, ST, CM',
#        'CAM, RWB, CM', 'CF, LW, RW', 'RB, LM', 'LB, RM', 'RM, LW, RW',
#        'CB, LWB, RWB', 'RM, RB, RWB', 'LB, CM, ST', 'ST, CF, RW',
#        'GK, RB', 'CAM, RB', 'CAM, RM, RB', 'ST, CM, RB', 'CM, CAM, CF',
#        'LW, RM, RW', 'CAM, RM, LW', 'ST, RM, RW', 'RM, ST, CF',
#        'RM, LW, ST', 'ST, LW, RM', 'LM, CM, CDM', 'CDM, CB, RM', 'ST, CB',
#        'LM, LB, ST', 'CB, RWB, RM', 'LW, RM, LM', 'CF, ST, CM',
#        'LM, CF, CAM', 'CF, RM, RWB', 'CB, LB, CDM', 'CDM, RM',
#        'CF, CM, LM', 'LM, RB, CB', 'CF, RM', 'RM, CF, ST', 'LM, RB',
#        'LB, RB, RW', 'CF, ST, RM', 'CM, LM, ST', 'CDM, RWB',
#        'LM, CDM, CM', 'CDM, CAM, LM', 'LB, CDM, LM', 'ST, CB, RB',
#        'LW, LM, RM', 'LW, CAM, LM', 'RW, CF, CAM', 'CB, RB, ST',
#        'ST, LW, CM', 'LWB, LM, RB', 'LB, RB, LM', 'RB, LWB', 'RW, LM, LW',
#        'CM, RB, CDM', 'CAM, LM, RW', 'CM, LM, LW', 'RM, CF, CAM',
#        'RB, CDM, LB', 'RB, RWB, LWB', 'CF, RW', 'LWB, LM, RWB',
#        'RB, RM, LM', 'RB, CB, LWB', 'RB, CM, CB', 'RM, LM, CDM',
#        'CAM, RW, CF', 'LB, CB, CDM', 'ST, CF, RM', 'CAM, LB',
#        'RW, RM, ST', 'RM, RWB, CAM', 'ST, LW, CF', 'ST, RW, CF',
#        'LM, ST, LWB', 'CM, CF, ST', 'CB, CAM', 'LM, LW, CF',
#        'RW, CAM, LW', 'RW, RB, LB', 'CB, ST, CAM', 'LW, CF, RW',
#        'LM, LB, CF', 'LB, RB, CDM', 'CF, LM', 'ST, RM, RWB', 'ST, LM, CF',
#        'LM, RM, RWB', 'LW, CAM, RM', 'LW, LWB', 'RM, CDM', 'ST, CM, CAM',
#        'CAM, LM, LB', 'LM, LWB, CB', 'CDM, ST', 'ST, RW, LM',
#        'CM, CB, RB', 'CF, CM, ST', 'CB, CDM, RM', 'LM, RM, CB', 'ST, RB',
#        'RB, LM, LB', 'LM, CDM, RM', 'LB, RB, LWB', 'RB, RWB, CM',
#        'LM, RW, ST', 'LB, LM, CM', 'RB, RM, CDM', 'LM, ST, CF', 'CDM, LM',
#        'CB, LWB, LB', 'LB, LW, LM', 'CDM, LB, CB', 'CB, LM',
#        'RW, LM, CAM', 'RW, RB, LM', 'RW, LW, RB', 'LB, LW, RB',
#        'RWB, LWB, RB', 'LWB, RWB, LB', 'RB, RM, CAM', 'CB, RM, RB',
#        'LB, LWB, CDM', 'LB, CM, CDM', 'RW, CF, LW', 'RWB, LWB, RM',
#        'RB, ST, CB', 'CF, RM, ST', 'LM, CDM', 'RWB, CB, RB',
#        'CDM, RW, RB', 'RW, CAM, LM', 'RB, RM, ST', 'LW, RW, LWB',
#        'LB, LWB, CM', 'LW, LM, CM', 'RW, RB, LW', 'LB, LM, CDM'],
#       dtype=object)

# %%
df[['Value','Wage']]
# Out:
#        Value  Wage
# 350      €8M  €12K
# 262    €3.4M  €41K
# 3348   €250K   €6K
# 3730   €750K   €6K
# 4207   €650K   €6K
# ...      ...   ...
# 15843  €575K   €1K
# 12487    €1M   €4K
# 12547  €1.2M   €2K
# 15200  €475K   €5K
# 12532  €475K  €500
#
# [16384 rows x 2 columns]

# %%
df[['Weight', 'Height']]
# Out:
#       Weight Height
# 350     68kg  171cm
# 262     92kg  192cm
# 3348    92kg  197cm
# 3730    78kg  188cm
# 4207    78kg  186cm
# ...      ...    ...
# 15843   75kg  183cm
# 12487   69kg  196cm
# 12547   75kg  178cm
# 15200   80kg  198cm
# 12532   71kg  178cm
#
# [16384 rows x 2 columns]

# %%
df['Weight'].unique()
# Out:
# array(['68kg', '92kg', '78kg', '80kg', '83kg', '70kg', '67kg', '71kg',
#        '95kg', '75kg', '73kg', '74kg', '81kg', '84kg', '85kg', '65kg',
#        '91kg', '88kg', '89kg', '87kg', '64kg', '69kg', '86kg', '76kg',
#        '93kg', '94kg', '183lbs', '77kg', '82kg', '101kg', '66kg',
#        '174lbs', '163lbs', '79kg', '170lbs', '157lbs', '181lbs', '60kg',
#        '90kg', '63kg', '72kg', '159lbs', '62kg', '110kg', '168lbs',
#        '100kg', '61kg', '97kg', '179lbs', '57kg', '148lbs', '165lbs',
#        '154lbs', '190lbs', '96kg', '58kg', '192lbs', '98kg', '107kg',
#        '56kg', '139lbs', '161lbs', '172lbs', '130lbs', '103kg', '196lbs',
#        '102kg', '203lbs', '185lbs', '176lbs', '104kg', '146lbs', '59kg',
#        '99kg', '55kg', '50kg', '54kg', '53kg', '52kg'], dtype=object)

# %%
#if df['Weight'].any() != df['Weight'].str.endswith('kg'):
 #   df['Weight'].apply((df['Weight']).astype('int') * 0.45359237)

# %%
df['Wage'].unique()
# Out:
# array(['€12K', '€41K', '€6K', '€2K', '€1K', '€11K', '€220K', '€30K',
#        '€950', '€49K', '€22K', '€9K', '€21K', '€5K', '€7K', '€33K',
#        '€750', '€23K', '€3K', '€16K', '€850', '€31K', '€10K', '€550',
#        '€14K', '€4K', '€600', '€15K', '€8K', '€13K', '€900', '€28K', '€0',
#        '€37K', '€29K', '€700', '€110K', '€35K', '€95K', '€32K', '€17K',
#        '€650', '€500', '€34K', '€25K', '€18K', '€100K', '€47K', '€20K',
#        '€43K', '€40K', '€800', '€19K', '€50K', '€36K', '€79K', '€24K',
#        '€300K', '€66K', '€63K', '€54K', '€65K', '€560K', '€26K', '€53K',
#        '€44K', '€42K', '€90K', '€27K', '€48K', '€51K', '€350K', '€81K',
#        '€130K', '€125K', '€58K', '€39K', '€85K', '€38K', '€46K', '€76K',
#        '€84K', '€45K', '€86K', '€200K', '€60K', '€115K', '€83K', '€170K',
#        '€260K', '€59K', '€72K', '€55K', '€62K', '€61K', '€56K', '€57K',
#        '€175K', '€87K', '€150K', '€64K', '€310K', '€89K', '€140K',
#        '€160K', '€70K', '€82K', '€120K', '€105K', '€68K', '€74K', '€71K',
#        '€240K', '€69K', '€190K', '€155K', '€78K', '€270K', '€250K',
#        '€165K', '€52K', '€370K', '€80K', '€290K', '€210K', '€73K',
#        '€135K', '€67K', '€75K', '€77K', '€88K', '€230K', '€195K', '€145K'],
#       dtype=object)

# %%
df['Wage'] = df['Wage'].str.replace('€', '')
df['Wage'] = df['Wage'].str.replace('K', '000')
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\2184279354.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Wage'] = df['Wage'].str.replace('€', '')
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\2184279354.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Wage'] = df['Wage'].str.replace('K', '000')

# %%
df['Wage'].unique()
# Out:
# array(['12000', '41000', '6000', '2000', '1000', '11000', '220000',
#        '30000', '950', '49000', '22000', '9000', '21000', '5000', '7000',
#        '33000', '750', '23000', '3000', '16000', '850', '31000', '10000',
#        '550', '14000', '4000', '600', '15000', '8000', '13000', '900',
#        '28000', '0', '37000', '29000', '700', '110000', '35000', '95000',
#        '32000', '17000', '650', '500', '34000', '25000', '18000',
#        '100000', '47000', '20000', '43000', '40000', '800', '19000',
#        '50000', '36000', '79000', '24000', '300000', '66000', '63000',
#        '54000', '65000', '560000', '26000', '53000', '44000', '42000',
#        '90000', '27000', '48000', '51000', '350000', '81000', '130000',
#        '125000', '58000', '39000', '85000', '38000', '46000', '76000',
#        '84000', '45000', '86000', '200000', '60000', '115000', '83000',
#        '170000', '260000', '59000', '72000', '55000', '62000', '61000',
#        '56000', '57000', '175000', '87000', '150000', '64000', '310000',
#        '89000', '140000', '160000', '70000', '82000', '120000', '105000',
#        '68000', '74000', '71000', '240000', '69000', '190000', '155000',
#        '78000', '270000', '250000', '165000', '52000', '370000', '80000',
#        '290000', '210000', '73000', '135000', '67000', '75000', '77000',
#        '88000', '230000', '195000', '145000'], dtype=object)

# %%
df['Wage'] = df['Wage'].astype('int')
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\4164688525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Wage'] = df['Wage'].astype('int')

# %%
df['Wage'].dtypes
# Out:
# dtype('int32')

# %%
df['Value']
# Out:
# 350        €8M
# 262      €3.4M
# 3348     €250K
# 3730     €750K
# 4207     €650K
#          ...
# 15843    €575K
# 12487      €1M
# 12547    €1.2M
# 15200    €475K
# 12532    €475K
# Name: Value, Length: 16384, dtype: object

# %%
df['Value'] = df['Value'].str.replace('€', '')
df['Value']= df['Value'].str.replace('K', '000')

df['Value'].unique()
# df[['Value']]
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\1784135846.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Value'] = df['Value'].str.replace('€', '')
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\1784135846.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Value']= df['Value'].str.replace('K', '000')
# array(['8M', '3.4M', '250000', '750000', '650000', '7M', '160000',
#        '525000', '350000', '80000', '5.5M', '63M', '1.9M', '1M', '0',
#        '240000', '12.5M', '275000', '625000', '325000', '475000',
#        '550000', '90000', '400000', '150000', '45000', '180000', '35000',
#        '425000', '25000', '4.9M', '575000', '50000', '220000', '1.2M',
#        '110000', '450000', '1.4M', '1.7M', '210000', '375000', '4.6M',
#        '4.8M', '120000', '230000', '1.5M', '2.1M', '1.6M', '190000',
#        '11M', '130000', '300000', '2.4M', '800000', '9.5M', '21M',
#        '600000', '13M', '1.1M', '70000', '60000', '3M', '3.7M', '500000',
#        '825000', '54M', '4.3M', '2.3M', '2.6M', '3.6M', '15.5M', '3.2M',
#        '6.5M', '1.3M', '925000', '1.8M', '100000', '700000', '32.5M',
#        '3.5M', '83.5M', '725000', '2.5M', '950000', '775000', '200000',
#        '33.5M', '8.5M', '24.5M', '9M', '10M', '875000', '103.5M', '10.5M',
#        '140000', '2.8M', '16.5M', '22.5M', '675000', '13.5M', '4M',
#        '14.5M', '2.7M', '900000', '2.9M', '6M', '2M', '3.1M', '17.5M',
#        '29.5M', '850000', '26M', '32M', '24M', '170000', '28.5M', '30M',
#        '2.2M', '12M', '7.5M', '975000', '3.3M', '3.9M', '18M', '20M',
#        '4.4M', '4.7M', '11.5M', '5M', '35M', '34.5M', '4.1M', '3.8M',
#        '51M', '25M', '36.5M', '19M', '22M', '36M', '14M', '4.5M', '29M',
#        '46.5M', '16M', '27M', '51.5M', '52.5M', '40000', '87.5M', '89.5M',
#        '17M', '31.5M', '20.5M', '57M', '37M', '25.5M', '26.5M', '53M',
#        '35.5M', '44.5M', '111M', '67.5M', '4.2M', '49.5M', '56M', '44M',
#        '38.5M', '65.5M', '15M', '54.5M', '41.5M', '18.5M', '132M',
#        '47.5M', '82M', '78M', '110M', '46M', '34M', '31M', '129M', '45M',
#        '79.5M', '21.5M', '23M', '77.5M', '42.5M', '40.5M', '28M', '40M',
#        '30.5M', '57.5M', '42M', '33M', '23.5M', '85M', '90.5M', '120M',
#        '45.5M', '76.5M', '72.5M', '81.5M', '27.5M', '109M', '71.5M',
#        '114.5M', '113M', '19.5M', '61.5M', '38M', '70M', '47M', '66M',
#        '37.5M', '55.5M', '62M', '120.5M', '43.5M', '88.5M', '58.5M',
#        '48M', '58M', '92M', '52M', '61M', '74.5M', '60.5M', '105.5M',
#        '92.5M', '103M', '102M', '43M', '95M', '67M', '39M', '55M', '81M',
#        '66.5M', '93.5M', '63.5M', '114M', '86.5M', '185.5M', '39.5M',
#        '124M', '99M', '121M', '50M', '73.5M', '56.5M', '62.5M'],
#       dtype=object)

# %%
df['Value'] = df['Value'].str.replace('M', '00000')
df['Value'] = df['Value'].str.replace('.', '0')
df['Value'] = df['Value'].astype('int')
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\254679232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Value'] = df['Value'].str.replace('M', '00000')
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\254679232.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Value'] = df['Value'].str.replace('.', '0')
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\254679232.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Value'] = df['Value'].str.replace('.', '0')
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\254679232.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Value'] = df['Value'].astype('int')

# %%
df['Value']
# Out:
# 350        800000
# 262      30400000
# 3348       250000
# 3730       750000
# 4207       650000
#            ...
# 15843      575000
# 12487      100000
# 12547    10200000
# 15200      475000
# 12532      475000
# Name: Value, Length: 16384, dtype: int32

# %%
df[['Height', 'Weight']]
# Out:
#       Height Weight
# 350    171cm   68kg
# 262    192cm   92kg
# 3348   197cm   92kg
# 3730   188cm   78kg
# 4207   186cm   78kg
# ...      ...    ...
# 15843  183cm   75kg
# 12487  196cm   69kg
# 12547  178cm   75kg
# 15200  198cm   80kg
# 12532  178cm   71kg
#
# [16384 rows x 2 columns]

# %%
df.Height.unique()
# Out:
# array(['171cm', '192cm', '197cm', '188cm', '186cm', '180cm', '185cm',
#        '183cm', '175cm', '187cm', '189cm', '178cm', '177cm', '195cm',
#        '179cm', '182cm', '184cm', '191cm', '190cm', '193cm', '173cm',
#        '176cm', '170cm', '181cm', '196cm', '6\'2"', '169cm', '194cm',
#        '174cm', '172cm', '6\'4"', '5\'9"', '5\'7"', '167cm', '5\'10"',
#        '168cm', '165cm', '198cm', '6\'3"', '161cm', '201cm', '199cm',
#        '6\'0"', '5\'11"', '6\'1"', '202cm', '158cm', '5\'4"', '163cm',
#        '166cm', '164cm', '162cm', '5\'6"', '6\'5"', '203cm', '206cm',
#        '157cm', '200cm', '160cm', '155cm', '159cm', '156cm'], dtype=object)

# %%
df.Weight.unique()
# Out:
# array(['68kg', '92kg', '78kg', '80kg', '83kg', '70kg', '67kg', '71kg',
#        '95kg', '75kg', '73kg', '74kg', '81kg', '84kg', '85kg', '65kg',
#        '91kg', '88kg', '89kg', '87kg', '64kg', '69kg', '86kg', '76kg',
#        '93kg', '94kg', '183lbs', '77kg', '82kg', '101kg', '66kg',
#        '174lbs', '163lbs', '79kg', '170lbs', '157lbs', '181lbs', '60kg',
#        '90kg', '63kg', '72kg', '159lbs', '62kg', '110kg', '168lbs',
#        '100kg', '61kg', '97kg', '179lbs', '57kg', '148lbs', '165lbs',
#        '154lbs', '190lbs', '96kg', '58kg', '192lbs', '98kg', '107kg',
#        '56kg', '139lbs', '161lbs', '172lbs', '130lbs', '103kg', '196lbs',
#        '102kg', '203lbs', '185lbs', '176lbs', '104kg', '146lbs', '59kg',
#        '99kg', '55kg', '50kg', '54kg', '53kg', '52kg'], dtype=object)

# %%
#Converting the Weight column to kg and also change to int
def fun(x):
    if 'lbs' in x:
        y = x.replace('lbs', '')
        y = int(y) * 0.454
        return int(round(y))
    else:
        return int(x.replace('kg', ''))
    
    
df['Weight'] = df['Weight'].map(fun)
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\954212051.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight'] = df['Weight'].map(fun)

# %%
df['Weight'].unique()
# Out:
# array([ 68,  92,  78,  80,  83,  70,  67,  71,  95,  75,  73,  74,  81,
#         84,  85,  65,  91,  88,  89,  87,  64,  69,  86,  76,  93,  94,
#         77,  82, 101,  66,  79,  60,  90,  63,  72,  62, 110, 100,  61,
#         97,  57,  96,  58,  98, 107,  56,  59, 103, 102, 104,  99,  55,
#         50,  54,  53,  52], dtype=int64)

# %%
# Convert the Height column to cm from inches and also to intergers
def func(x):
    if '"' in x:
        y = x.replace('"', '')
        y = y.split("\'")
        y = int(y[0]) + int(y[1]) * 0.0833
        y = 30.48 * y
        return int(round(y))
    else:
        return int(x.replace('cm', ''))
    
df['Height'] = df['Height'].map(func)
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\321314870.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Height'] = df['Height'].map(func)

# %%
df.Height.describe()
# Out:
# count    16384.000000
# mean       181.284729
# std          6.843704
# min        155.000000
# 25%        176.000000
# 50%        181.000000
# 75%        186.000000
# max        206.000000
# Name: Height, dtype: float64

# %%
df['Contract']
# Out:
# 350      2018 - 2021
# 262      2019 - 2021
# 3348     2020 - 2021
# 3730     2008 - 2021
# 4207     2017 - 2021
#             ...
# 15843    2020 - 2024
# 12487    2020 - 2023
# 12547    2020 - 2022
# 15200    2018 - 2021
# 12532    2020 - 2024
# Name: Contract, Length: 16384, dtype: object

# %%
df['IR']
# Out:
# 350      4 ★
# 262      4 ★
# 3348     2 ★
# 3730     1 ★
# 4207     1 ★
#         ...
# 15843    1 ★
# 12487    1 ★
# 12547    1 ★
# 15200    1 ★
# 12532    1 ★
# Name: IR, Length: 16384, dtype: object

# %%
df['IR'] = df['IR'].str.replace("★", '')
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\2275997594.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IR'] = df['IR'].str.replace("★", '')

# %%
df['IR']
# Out:
# 350      4
# 262      4
# 3348     2
# 3730     1
# 4207     1
#          ..
# 15843    1
# 12487    1
# 12547    1
# 15200    1
# 12532    1
# Name: IR, Length: 16384, dtype: object

# %%
df[['W/F', 'SM']]
# Out:
#        W/F  SM
# 350    4 ★  4★
# 262    2 ★  1★
# 3348   4 ★  1★
# 3730   3 ★  3★
# 4207   4 ★  3★
# ...    ...  ..
# 15843  3 ★  2★
# 12487  3 ★  1★
# 12547  3 ★  3★
# 15200  2 ★  1★
# 12532  3 ★  2★
#
# [16384 rows x 2 columns]

# %%
df['W/F'] = df['W/F'].str.replace("★", '')
df['SM'] = df['SM'].str.replace("★", '')
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\1404661309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['W/F'] = df['W/F'].str.replace("★", '')
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\1404661309.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SM'] = df['SM'].str.replace("★", '')

# %%
df['Contract']
# Out:
# 350      2018 - 2021
# 262      2019 - 2021
# 3348     2020 - 2021
# 3730     2008 - 2021
# 4207     2017 - 2021
#             ...
# 15843    2020 - 2024
# 12487    2020 - 2023
# 12547    2020 - 2022
# 15200    2018 - 2021
# 12532    2020 - 2024
# Name: Contract, Length: 16384, dtype: object

# %%
df['Contract_Year_Start'] = ''
df['Contract_Year_Ends'] = ''
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\2746859456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Contract_Year_Start'] = ''
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\2746859456.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Contract_Year_Ends'] = ''

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Value', 'Wage',
#        'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
#        'DRI', 'DEF', 'PHY', 'Hits', 'Contract_Year_Start',
#        'Contract_Year_Ends'],
#       dtype='object')

# %%
def main(k):
    start = []
    gen = k.to_list()
    for i in gen:
        #end.append(i[:4])
        start.append(i[:-7])
        # end.append(i[1])
    return start
                
    
df['Contract_Year_Start'] = main(df['Contract'])


def main1(k):
    end = []
    gen = k.to_list()
    for i in gen:
        end.append(i[-7:])
        #start.append(i[0:4])
        # end.append(i[1])
    return end
                
    
df['Contract_Year_Ends'] = main1(df['Contract'])
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\3211008343.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Contract_Year_Start'] = main(df['Contract'])
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\3211008343.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Contract_Year_Ends'] = main1(df['Contract'])

# %%
df[['Contract_Year_Start', 'Contract_Year_Ends']]
# Out:
#       Contract_Year_Start Contract_Year_Ends
# 350                  2018             - 2021
# 262                  2019             - 2021
# 3348                 2020             - 2021
# 3730                 2008             - 2021
# 4207                 2017             - 2021
# ...                   ...                ...
# 15843                2020             - 2024
# 12487                2020             - 2023
# 12547                2020             - 2022
# 15200                2018             - 2021
# 12532                2020             - 2024
#
# [16384 rows x 2 columns]

# %%
df.head()
# Out:
#         ID             Name               LongName  \
# 350     41          Iniesta   Andrés Iniesta Luján
# 262   1179        G. Buffon       Gianluigi Buffon
# 3348  2147  M. Stekelenburg   Maarten Stekelenburg
# 3730  3281        Tarantini  Ricardo José Monteiro
# 4207  3467             Yuri  Yuri de Souza Fonseca
#
#                                               photoUrl  \
# 350   https://cdn.sofifa.com/players/000/041/21_60.png
# 262   https://cdn.sofifa.com/players/001/179/21_60.png
# 3348  https://cdn.sofifa.com/players/002/147/21_60.png
# 3730  https://cdn.sofifa.com/players/003/281/21_60.png
# 4207  https://cdn.sofifa.com/players/003/467/21_60.png
#
#                                               playerUrl  Nationality  Age  \
# 350   http://sofifa.com/player/41/andres-iniesta-luj...        Spain   36
# 262   http://sofifa.com/player/1179/gianluigi-buffon...        Italy   42
# 3348  http://sofifa.com/player/2147/maarten-stekelen...  Netherlands   37
# 3730  http://sofifa.com/player/3281/ricardo-jose-mon...     Portugal   36
# 4207  http://sofifa.com/player/3467/yuri-de-souza-fo...       Brazil   37
#
#       ↓OVA  POT             Club  ...  IR PAC  SHO  PAS DRI  DEF PHY Hits  \
# 350     81   81      Vissel Kobe  ...  4   58   70   85  85   63  59  130
# 262     82   82         Juventus  ...  4   77   76   74  78   33  91  131
# 3348    72   72             Ajax  ...  2   69   71   72  70   33  73   23
# 3730    72   72       Rio Ave FC  ...  1   50   67   71  70   70  67    4
# 4207    71   71  SD Ponferradina  ...  1   66   74   59  69   35  69    5
#
#       Contract_Year_Start  Contract_Year_Ends
# 350                  2018              - 2021
# 262                  2019              - 2021
# 3348                 2020              - 2021
# 3730                 2008              - 2021
# 4207                 2017              - 2021
#
# [5 rows x 78 columns]

# %%
df[['playerUrl']]
# Out:
#                                                playerUrl
# 350    http://sofifa.com/player/41/andres-iniesta-luj...
# 262    http://sofifa.com/player/1179/gianluigi-buffon...
# 3348   http://sofifa.com/player/2147/maarten-stekelen...
# 3730   http://sofifa.com/player/3281/ricardo-jose-mon...
# 4207   http://sofifa.com/player/3467/yuri-de-souza-fo...
# ...                                                  ...
# 15843  http://sofifa.com/player/259205/naouirou-ahama...
# 12487  http://sofifa.com/player/259206/antonis-stergi...
# 12547  http://sofifa.com/player/259209/mateo-bajamich...
# 15200  http://sofifa.com/player/259211/oytun-ozdogan/...
# 12532  http://sofifa.com/player/259214/wayde-jooste/2...
#
# [16384 rows x 1 columns]

# %%
df['Contract_Year_Ends'].unique()
# Out:
# array([' - 2021', ' - 2022', ' - 2023', ' - 2020', ' - 2025', 'On Loan',
#        'Free', ' - 2024', ' - 2026', ' - 2028', ' - 2027'], dtype=object)

# %%
df['Contract_Year_Start'].unique()
# Out:
# array(['2018', '2019', '2020', '2008', '2017', '2014', '2016', '2007',
#        '2015', '2003', '2011', '2013', 'Jun 30, 2021 ', '2010', '',
#        '2012', '2009', '2002', '2005', '1998', '2006', 'May 31, 2021 ',
#        '2004', 'Dec 31, 2020 ', 'Jan 30, 2021 ', 'Jan 1, 2021 ',
#        'Dec 31, 2021 ', 'Jan 31, 2021 ', 'Jul 5, 2021 ', 'Jun 30, 2022 ',
#        'Nov 22, 2020 ', 'Nov 27, 2021 ', 'Jun 23, 2021 ', 'Jan 17, 2021 ',
#        'Jul 1, 2021 ', 'Dec 30, 2021 ', 'Jan 4, 2021 ', 'Jan 3, 2021 ',
#        'Nov 30, 2020 ', 'Aug 31, 2021 ', 'Jul 31, 2021 ', 'May 31, 2022 ',
#        'Jun 30, 2023 ', 'Dec 30, 2020 '], dtype=object)

# %%
df['Contract_Year_Ends'] = df['Contract_Year_Ends'].str.replace(" - ", '')
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_9208\4256350459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Contract_Year_Ends'] = df['Contract_Year_Ends'].str.replace(" - ", '')

# %%
df['Contract_Year_Ends'].unique()
# Out:
# array(['2021', '2022', '2023', '2020', '2025', 'On Loan', 'Free', '2024',
#        '2026', '2028', '2027'], dtype=object)

# %%
df
# Out:
#            ID             Name               LongName  \
# 350        41          Iniesta   Andrés Iniesta Luján
# 262      1179        G. Buffon       Gianluigi Buffon
# 3348     2147  M. Stekelenburg   Maarten Stekelenburg
# 3730     3281        Tarantini  Ricardo José Monteiro
# 4207     3467             Yuri  Yuri de Souza Fonseca
# ...       ...              ...                    ...
# 15843  259205       N. Ahamada       Naouirou Ahamada
# 12487  259206    A. Stergiakis     Antonis Stergiakis
# 12547  259209      M. Bajamich         Mateo Bajamich
# 15200  259211       O. Özdoğan          Oytun Özdoğan
# 12532  259214        W. Jooste           Wayde Jooste
#
#                                                photoUrl  \
# 350    https://cdn.sofifa.com/players/000/041/21_60.png
# 262    https://cdn.sofifa.com/players/001/179/21_60.png
# 3348   https://cdn.sofifa.com/players/002/147/21_60.png
# 3730   https://cdn.sofifa.com/players/003/281/21_60.png
# 4207   https://cdn.sofifa.com/players/003/467/21_60.png
# ...                                                 ...
# 15843  https://cdn.sofifa.com/players/259/205/21_60.png
# 12487  https://cdn.sofifa.com/players/259/206/21_60.png
# 12547  https://cdn.sofifa.com/players/259/209/21_60.png
# 15200  https://cdn.sofifa.com/players/259/211/21_60.png
# 12532  https://cdn.sofifa.com/players/259/214/21_60.png
#
#                                                playerUrl   Nationality  Age  \
# 350    http://sofifa.com/player/41/andres-iniesta-luj...         Spain   36
# 262    http://sofifa.com/player/1179/gianluigi-buffon...         Italy   42
# 3348   http://sofifa.com/player/2147/maarten-stekelen...   Netherlands   37
# 3730   http://sofifa.com/player/3281/ricardo-jose-mon...      Portugal   36
# 4207   http://sofifa.com/player/3467/yuri-de-souza-fo...        Brazil   37
# ...                                                  ...           ...  ...
# 15843  http://sofifa.com/player/259205/naouirou-ahama...        France   18
# 12487  http://sofifa.com/player/259206/antonis-stergi...        Greece   21
# 12547  http://sofifa.com/player/259209/mateo-bajamich...     Argentina   20
# 15200  http://sofifa.com/player/259211/oytun-ozdogan/...        Turkey   22
# 12532  http://sofifa.com/player/259214/wayde-jooste/2...  South Africa   28
#
#        ↓OVA  POT              Club  ...  IR PAC  SHO  PAS DRI  DEF PHY Hits  \
# 350      81   81       Vissel Kobe  ...  4   58   70   85  85   63  59  130
# 262      82   82          Juventus  ...  4   77   76   74  78   33  91  131
# 3348     72   72              Ajax  ...  2   69   71   72  70   33  73   23
# 3730     72   72        Rio Ave FC  ...  1   50   67   71  70   70  67    4
# 4207     71   71   SD Ponferradina  ...  1   66   74   59  69   35  69    5
# ...     ...  ...               ...  ...  ..  ..  ...  ...  ..  ...  ..  ...
# 15843    59   77     VfB Stuttgart  ...  1   64   48   58  62   53  58   13
# 12487    63   77  Blackburn Rovers  ...  1   61   63   66  72   32  59    7
# 12547    63   78    Houston Dynamo  ...  1   71   60   52  63   27  57    3
# 15200    60   68     Fenerbahçe SK  ...  1   59   60   64  61   24  62    4
# 12532    63   63   Orlando Pirates  ...  1   68   64   59  67   30  53    2
#
#        Contract_Year_Start  Contract_Year_Ends
# 350                   2018                2021
# 262                   2019                2021
# 3348                  2020                2021
# 3730                  2008                2021
# 4207                  2017                2021
# ...                    ...                 ...
# 15843                 2020                2024
# 12487                 2020                2023
# 12547                 2020                2022
# 15200                 2018                2021
# 12532                 2020                2024
#
# [16384 rows x 78 columns]

# %%
df = df.rename(columns = {
    'Value' : 'Value(€)',
    'IR' : 'Ratings(★)',
    'Contract_Year_Start' : 'Contract Year Start',
    'Contract_Year_Ends' : 'Contract Year Ends'
})

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Value(€)', 'Wage',
#        'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'Ratings(★)', 'PAC', 'SHO',
#        'PAS', 'DRI', 'DEF', 'PHY', 'Hits', 'Contract Year Start',
#        'Contract Year Ends'],
#       dtype='object')

# %%
plt.figure(figsize=(35,8))
sns.countplot(data = df, x='Nationality')
plt.xticks(rotation = 90)
plt.grid()

# %%
plt.figure(figsize=(25,8))
sns.countplot(data = df, x='Contract Year Start')
plt.xticks(rotation = 90)
plt.grid()

# %%
plt.figure(figsize=(25,8))
sns.countplot(data = df, x='Contract Year Ends')
plt.xticks(rotation = 90)
plt.grid()

# %%
df[['Joined']]
# Out:
#              Joined
# 350    Jul 16, 2018
# 262     Jul 4, 2019
# 3348    Aug 5, 2020
# 3730    Jul 1, 2008
# 4207   Jan 15, 2017
# ...             ...
# 15843   Sep 1, 2020
# 12487   Oct 6, 2020
# 12547   Oct 5, 2020
# 15200  Jan 29, 2018
# 12532   Oct 6, 2020
#
# [16384 rows x 1 columns]

# %%
df['Year Joined'] = pd.DatetimeIndex(df['Joined']).year
df['Month Joined'] = pd.DatetimeIndex(df['Joined']).month_name()
df['Day Joined'] = pd.DatetimeIndex(df['Joined']).day_name()
df['Joined'] = pd.datetime(df['Joined'])

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Value(€)', 'Wage',
#        'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'Ratings(★)', 'PAC', 'SHO',
#        'PAS', 'DRI', 'DEF', 'PHY', 'Hits', 'Contract Year Start',
#        'Contract Year Ends', 'Year Joined', 'Month Joined', 'Day Joined'],
#       dtype='object')

# %%
df
# Out:
#            ID             Name               LongName  \
# 350        41          Iniesta   Andrés Iniesta Luján
# 262      1179        G. Buffon       Gianluigi Buffon
# 3348     2147  M. Stekelenburg   Maarten Stekelenburg
# 3730     3281        Tarantini  Ricardo José Monteiro
# 4207     3467             Yuri  Yuri de Souza Fonseca
# ...       ...              ...                    ...
# 15843  259205       N. Ahamada       Naouirou Ahamada
# 12487  259206    A. Stergiakis     Antonis Stergiakis
# 12547  259209      M. Bajamich         Mateo Bajamich
# 15200  259211       O. Özdoğan          Oytun Özdoğan
# 12532  259214        W. Jooste           Wayde Jooste
#
#                                                photoUrl  \
# 350    https://cdn.sofifa.com/players/000/041/21_60.png
# 262    https://cdn.sofifa.com/players/001/179/21_60.png
# 3348   https://cdn.sofifa.com/players/002/147/21_60.png
# 3730   https://cdn.sofifa.com/players/003/281/21_60.png
# 4207   https://cdn.sofifa.com/players/003/467/21_60.png
# ...                                                 ...
# 15843  https://cdn.sofifa.com/players/259/205/21_60.png
# 12487  https://cdn.sofifa.com/players/259/206/21_60.png
# 12547  https://cdn.sofifa.com/players/259/209/21_60.png
# 15200  https://cdn.sofifa.com/players/259/211/21_60.png
# 12532  https://cdn.sofifa.com/players/259/214/21_60.png
#
#                                                playerUrl   Nationality  Age  \
# 350    http://sofifa.com/player/41/andres-iniesta-luj...         Spain   36
# 262    http://sofifa.com/player/1179/gianluigi-buffon...         Italy   42
# 3348   http://sofifa.com/player/2147/maarten-stekelen...   Netherlands   37
# 3730   http://sofifa.com/player/3281/ricardo-jose-mon...      Portugal   36
# 4207   http://sofifa.com/player/3467/yuri-de-souza-fo...        Brazil   37
# ...                                                  ...           ...  ...
# 15843  http://sofifa.com/player/259205/naouirou-ahama...        France   18
# 12487  http://sofifa.com/player/259206/antonis-stergi...        Greece   21
# 12547  http://sofifa.com/player/259209/mateo-bajamich...     Argentina   20
# 15200  http://sofifa.com/player/259211/oytun-ozdogan/...        Turkey   22
# 12532  http://sofifa.com/player/259214/wayde-jooste/2...  South Africa   28
#
#        ↓OVA  POT              Club  ... PAS DRI  DEF  PHY Hits  \
# 350      81   81       Vissel Kobe  ...  85  85   63   59  130
# 262      82   82          Juventus  ...  74  78   33   91  131
# 3348     72   72              Ajax  ...  72  70   33   73   23
# 3730     72   72        Rio Ave FC  ...  71  70   70   67    4
# 4207     71   71   SD Ponferradina  ...  59  69   35   69    5
# ...     ...  ...               ...  ...  ..  ..  ...  ...  ...
# 15843    59   77     VfB Stuttgart  ...  58  62   53   58   13
# 12487    63   77  Blackburn Rovers  ...  66  72   32   59    7
# 12547    63   78    Houston Dynamo  ...  52  63   27   57    3
# 15200    60   68     Fenerbahçe SK  ...  64  61   24   62    4
# 12532    63   63   Orlando Pirates  ...  59  67   30   53    2
#
#        Contract Year Start Contract Year Ends Year Joined  Month Joined  \
# 350                   2018               2021        2018          July
# 262                   2019               2021        2019          July
# 3348                  2020               2021        2020        August
# 3730                  2008               2021        2008          July
# 4207                  2017               2021        2017       January
# ...                    ...                ...         ...           ...
# 15843                 2020               2024        2020     September
# 12487                 2020               2023        2020       October
# 12547                 2020               2022        2020       October
# 15200                 2018               2021        2018       January
# 12532                 2020               2024        2020       October
#
#        Day Joined
# 350        Monday
# 262      Thursday
# 3348    Wednesday
# 3730      Tuesday
# 4207       Sunday
# ...           ...
# 15843     Tuesday
# 12487     Tuesday
# 12547      Monday
# 15200      Monday
# 12532     Tuesday
#
# [16384 rows x 81 columns]

# %%
df.columns[10:61]
# Out:
# Index(['Contract', 'Positions', 'Height', 'Weight', 'Preferred Foot', 'BOV',
#        'Best Position', 'Joined', 'Value(€)', 'Wage', 'Release Clause',
#        'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy',
#        'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve',
#        'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning'],
#       dtype='object')

# %%
plt.figure(figsize=(20,5))
sns.countplot(data = df, x =df.Positions.iloc[:500])
plt.xticks(rotation = 90)
plt.grid()

# %%
df.Nationality.unique()
# Out:
# array(['Spain', 'Italy', 'Netherlands', 'Portugal', 'Brazil', 'England',
#        'France', 'Paraguay', 'Japan', 'United States', 'Sweden',
#        'Belgium', 'Argentina', 'Scotland', 'Norway', 'Northern Ireland',
#        'Switzerland', 'Republic of Ireland', 'Jamaica', 'Wales',
#        'Germany', 'Poland', 'Austria', 'Chile', 'Ivory Coast', 'Turkey',
#        'Denmark', 'Iceland', 'Canada', 'Korea Republic', 'Albania',
#        'Nigeria', 'North Macedonia', 'Uruguay', 'Madagascar', 'Mexico',
#        'Estonia', 'Slovenia', 'Hungary', 'Ukraine', 'Kosovo', 'Romania',
#        'Russia', 'Greece', 'Finland', 'Ethiopia', 'Australia',
#        'Czech Republic', 'Peru', 'China PR', 'Bolivia', 'Burkina Faso',
#        'Togo', 'Panama', 'Morocco', 'Bosnia Herzegovina', 'Benin',
#        'Israel', 'Cameroon', 'South Africa', 'Cyprus', 'Haiti',
#        'Slovakia', 'Colombia', 'Eritrea', 'Palestine', 'Croatia',
#        'Ecuador', 'Algeria', 'Ghana', 'Honduras', 'Egypt', 'Costa Rica',
#        'Sierra Leone', 'New Zealand', 'Serbia', 'Lithuania', 'Azerbaijan',
#        'Senegal', 'DR Congo', 'Cape Verde', 'Bulgaria', 'Montenegro',
#        'Saudi Arabia', 'Gambia', 'Uzbekistan', 'Moldova', 'Venezuela',
#        'Congo', 'Kazakhstan', 'Aruba', 'Comoros', 'Guinea', 'Guyana',
#        'Georgia', 'Latvia', 'Luxembourg', 'Mozambique', 'Gabon', 'Mali',
#        'Kenya', 'Curacao', 'Iran', 'Zambia', 'Montserrat', 'Tunisia',
#        'Guam', 'Cuba', 'Saint Kitts and Nevis', 'Armenia', 'Andorra',
#        'Philippines', 'Angola', 'Liechtenstein', 'Thailand',
#        'Guinea Bissau', 'Zimbabwe', 'Korea DPR', 'Grenada',
#        'Faroe Islands', 'United Arab Emirates', 'Antigua & Barbuda',
#        'New Caledonia', 'Equatorial Guinea', 'Iraq', 'Barbados',
#        'Central African Republic', 'Puerto Rico', 'Bermuda', 'Libya',
#        'Burundi', 'São Tomé & Príncipe', 'Chinese Taipei', 'Malta',
#        'Syria', 'Uganda', 'Saint Lucia', 'Trinidad & Tobago', 'Lebanon',
#        'Namibia', 'El Salvador', 'Tanzania', 'Malawi', 'Liberia',
#        'Dominican Republic', 'Mauritania', 'Jordan', 'Chad',
#        'South Sudan', 'Belize', 'Papua New Guinea', 'Sudan', 'Rwanda',
#        'Afghanistan', 'Guatemala', 'Macau', 'India', 'Niger', 'Belarus',
#        'Singapore'], dtype=object)

# %%
df[df.Nationality.isin(
    ['Spain']
)].groupby(
    ['Nationality', "Age"]
).Nationality.count().unstack().plot(kind='bar', title='Plot showing the Highest And Lowest Age By Nationality', grid=True, fontsize=10)
plt.legend(title='Age', fontsize=10)
plt.figure(figsize=(25,6))
